# %%
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
import math
import numpy as np

# %% [markdown]
# ## 1.

# %%
W = [[5, 3, 0, 0],
     [0, 1, 8, 4]]
V = [[0, 6], 
     [6, 0]]
a = [0, 4, 6, 10]
b = [2, 0, 8, 4]
n = 2
m = 4

# %% [markdown]
# ### (a)
# #### Non-linear Form
# ##### Decision Variables
# $x_j, y_j, \forall j \in \text{facilities}$: 新據點的兩軸座標
# ##### Model
# $\text{min}f_1 + f_2$
# x-axis: $f_1 = \displaystyle{\sum_{1 \leq j < k \leq n} v_{jk} |x_j - x_k| + \sum_{j=1}^{n} \sum_{i=1}^{m}w_{ji}}|x_j-a_i|$
# y-axis: $f_2 = \displaystyle{\sum_{1 \leq j < k \leq n} v_{jk} |y_j - y_k| + \sum_{j=1}^{n} \sum_{i=1}^{m}w_{ji}}|y_j-b_i|$
# $\text{s.t.}$
# $x_j, y_j \geq 0, \forall j \in \text{facilities}$
# #### Linear Form
# ##### Decision Variables
# $x_j, y_j, \forall j \in \text{facilities}$: 新據點的兩軸座標
# $p^X_{jk}$: 新據點j到新據點k在x軸上的左邊幾單位
# $q^X_{jk}$: 新據點j到新據點k在x軸上的右邊幾單位
# $r^X_{ji}$: 新據點j到舊據點i在x軸上的右邊幾單位
# $s^X_{ji}$: 新據點j到舊據點i在x軸上的左邊幾單位
# $p^Y_{jk}$: 新據點j到新據點k在y軸上的左邊幾單位
# $q^Y_{jk}$: 新據點j到新據點k在y軸上的右邊幾單位
# $r^Y_{ji}$: 新據點j到舊據點i在y軸上的右邊幾單位
# $s^Y_{ji}$: 新據點j到舊據點i在y軸上的左邊幾單位
# ##### Model
# $\text{min}f_1^\prime + f_2^\prime$, where
# x-axis: $f_1^\prime = \displaystyle{\sum_{1 \leq j < k \leq n} v_{jk} (p^X_{jk} + q^X_{jk}) + \sum_{j=1}^{n} \sum_{i=1}^{m}w_{ji}(r^X_{ji} + s^X_{ji})}$
# y-axis: $f_2^\prime = \displaystyle{\sum_{1 \leq j < k \leq n} v_{jk} (p^Y_{jk} + q^Y_{jk}) + \sum_{j=1}^{n} \sum_{i=1}^{m}w_{ji}(r^Y_{ji} + s^Y_{ji})}$
# $\text{s.t.}$
# $x_j - q^X_{jk} + p^X_{jk} = x_k, 1 \leq j < k \leq n$
# $x_j - r^X_{ji} + s^X_{ji} = a_i, 1 \leq i \leq m, 1 \leq j \leq n$
# $y_j - q^Y_{jk} + p^Y_{jk} = y_k, 1 \leq j < k \leq n$
# $y_j - r^Y_{ji} + s^Y_{ji} = b_i, 1 \leq i \leq m, 1 \leq j \leq n$
# $x_j, x_k, r^X_{ji}, s^X_{ji}, q^X_{jk}, p^X_{jk}, y_j, y_k, r^Y_{ji}, s^Y_{ji}, q^Y_{jk}, p^Y_{jk} \geq 0, \forall j \in \text{facilities}$
# ### (b)

# %%
model = gp.Model("FLP")
# Out:
# Academic license - for non-commercial use only - expires 2021-05-28
# Using license file /home/cu2189191862/gurobi.lic

# %%
x = model.addVars(2, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="x")
y = model.addVars(2, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="y")
p_X = model.addVars(2, 2, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="p_X")
q_X = model.addVars(2, 2, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="q_X")
r_X = model.addVars(2, 4, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="r_X")
s_X = model.addVars(2, 4, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="s_X")
p_Y = model.addVars(2, 2, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="p_Y")
q_Y = model.addVars(2, 2, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="q_Y")
r_Y = model.addVars(2, 4, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="r_Y")
s_Y = model.addVars(2, 4, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="s_Y")

# %%
f_prime1 = gp.quicksum(V[j][k] * (p_X[j, k] + q_X[j, k]) for j in range(n) for k in range(n) if j < k) + \
           gp.quicksum(W[j][i] * (r_X[j, i] + s_X[j, i]) for j in range(n) for i in range(m))
f_prime2 = gp.quicksum(V[j][k] * (p_Y[j, k] + q_Y[j, k]) for j in range(n) for k in range(n) if j < k) + \
           gp.quicksum(W[j][i] * (r_Y[j, i] + s_Y[j, i]) for j in range(n) for i in range(m))

model.setObjective(f_prime1 + f_prime2, GRB.MINIMIZE)

# %%
model.addConstrs(x[j] - q_X[j, k] + p_X[j, k] - x[k] == 0 for j in range(n) for k in range(n) if j < k)
model.addConstrs(x[j] - r_X[j, i] + s_X[j, i] == a[i] for j in range(n) for i in range(m))
model.addConstrs(y[j] - q_Y[j, k] + p_Y[j, k] == y[k] for j in range(n) for k in range(n) if j < k)
model.addConstrs(y[j] - r_Y[j, i] + s_Y[j, i] == b[i] for j in range(n) for i in range(m))
# Out:
# {(0, 0): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 1): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 2): <gurobi.Constr *Awaiting Model Update*>,
#  (0, 3): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 0): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 1): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 2): <gurobi.Constr *Awaiting Model Update*>,
#  (1, 3): <gurobi.Constr *Awaiting Model Update*>}

# %%
model.write('q1.lp')

model.optimize()
# Out:
# Gurobi Optimizer version 9.1.1 build v9.1.1rc0 (linux64)
# Thread count: 32 physical cores, 64 logical processors, using up to 32 threads
# Optimize a model with 18 rows, 52 columns and 56 nonzeros
# Model fingerprint: 0x118aeb53
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 8e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [2e+00, 1e+01]
# Presolve removed 9 rows and 30 columns
# Presolve time: 0.01s
# Presolved: 9 rows, 22 columns, 29 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    0.0000000e+00   3.800000e+01   0.000000e+00      0s
#        8    1.0400000e+02   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  1.040000000e+02

# %% [markdown]
# ### (c)

# %%
for j in range(n):
    print("new facility {} located at: ({}, {})".format(j, model.getAttr('x', x)[j], model.getAttr('x', y)[j]))

print("objective value:", model.objVal)
# Out:
# new facility 0 located at: (4.0, 2.0)
# new facility 1 located at: (6.0, 4.0)
# objective value: 104.0

# %%
import matplotlib.pyplot as plt

xs = list()
ys = list()
for j in range(n):
    xs.append(model.getAttr('x', x)[j])
    ys.append(model.getAttr('x', y)[j])

plt.scatter(xs, ys)
plt.scatter(a, b, c='k')
print("黑色的點是舊的據點，藍色是新的")
# Out:
# 黑色的點是舊的據點，藍色是新的

# %% [markdown]
# ## 2.
# ### (a)
# 令在$x$右邊的點的集合為$R$，在$x$左邊的點的集合為$L$，$W_i$為到點$i$的權重
# 則$x$每向右$1$單位，相對於每個在右處的點的距離都會下降$1$單位、每個在左處的點的距離都會上升$1$單位，
# 根據斜率的定義：$x$每向右一單位，$f(x)$的改變量
# 可以得知，以每個點的相對改變量乘上$W_i$的和就是斜率：$\displaystyle{\text{slope} = \sum_{i \in L}W_i - \sum_{i \in R}W_i}$
#
# ### (b)
# 因為這是一個convex function，亦即函數上的任意兩點連線段必在函數的上方，所以最佳解所在的位置會在斜率的正負號轉折之處(Optimality properties is because of the convexity of the function)，綜合(a)題的結論，我們知道函數的最低點必定是向右的weight與向左的weight抵銷到為$0$的情況，也就是在這個點才會發生斜率的正負號轉折。

# %% [markdown]
# ## 3.
# 4個長為8寬為16、5個長為9寬為9、3個長為18寬為3的長方形
# ### (a)

# %% [markdown]
# #### Variables
# $x$：總所需面積的$x$軸長度
# $y$：總所需面積的$y$軸長度
# $x_i^\prime$：長方形$i$的中心點和原點沿著$x$軸的距離，$i \in \text{rectangles}$
# $y_i^\prime$：長方形$i$的中心點和原點沿著$y$軸的距離，$i \in \text{rectangles}$
# $s_i$：長方形$i$的方向，$1$為$p$軸平行$x$軸，$0$為$p$軸平行$y$軸，$i \in \text{rectangles}$
# $u_{ik}, v_{ik}$：分別表示長方形$i$與長方形$k$之間的平行與垂直相對位置，$i, k \in \text{rectangles}, i \neq k$
# $\alpha^X_j, \beta^X_j$：對$\text{ln }x$線性化所需的變數，$2 \leq j \leq m^X$
# $\alpha^Y_j, \beta^Y_j$：對$\text{ln }y$線性化所需的變數，$2 \leq j \leq m^Y$
#
#
# #### Model
# $\displaystyle{\text{min } \text{ln }a_1 + t^X_1(x - a_1) + \sum_{j=2}^{m^X-1}(t^X_j - t^X_{j-1})(a_j \alpha^X_j + x - a_j - \beta^X_j) + \text{ln }b_1 + t^Y_1(y - b_1) + \sum_{j=2}^{m^Y-1}(t^Y_j - t^Y_{j-1})(b_j \alpha^Y_j + y - b_j - \beta^Y_j)}$
# $\text{s.t.}$
# $- \bar{x} \alpha^X_j \leq x - a_j \leq \bar{x}(1 - \alpha^X_j)$
# $- \bar{x} \alpha^X_j \leq \beta^X_j \leq \bar{x} \alpha^X_{j} $
# $\bar{x} (\alpha^X_j - 1) + x \leq \beta^X_j \leq \bar{x} (1 - \alpha^X_j) + x $
# $\alpha^X_j \geq \alpha^X_{j-1}$
# $\forall 2 \leq j \leq m^X$
#
# $- \bar{y} \alpha^Y_j \leq y - b_j \leq \bar{y}(1 - \alpha^Y_j)$
# $- \bar{y} \alpha^Y_j \leq \beta^Y_j \leq \bar{y} \alpha^Y_{j} $
# $\bar{y} (\alpha^Y_j - 1) + y \leq \beta^Y_j \leq \bar{y} (1 - \alpha^Y_j) + y $
# $\alpha^Y_j \geq \alpha^Y_{j-1}$
# $\forall 2 \leq j \leq m^Y$
#
# $(x^\prime_i - x^\prime_k) + u_{ik} \bar{x} + v_{ik} \bar{x} \geq \frac{1}{2} (p_i s_i + q_i (1-s_i) + p_k s_k + q_k (1-s_k)), \forall i,k \in \text{rectangles} $
# $(x^\prime_k - x^\prime_i) + (1 - u_{ik}) \bar{x} + v_{ik} \bar{x} \geq \frac{1}{2} (p_i s_i + q_i (1-s_i) + p_k s_k + q_k (1-s_k)), \forall i,k \in \text{rectangles} $
# $(y^\prime_i - y^\prime_k) + u_{ik} \bar{y} + (1 - v_{ik}) \bar{y} \geq \frac{1}{2} (p_i (1 - s_i) + q_i s_i + p_k (1 - s_k) + q_k s_k), \forall i,k \in \text{rectangles} $
# $(y^\prime_k - y^\prime_i) + (1 - u_{ik}) \bar{y} + (1 - v_{ik}) \bar{y} \geq \frac{1}{2} (p_i (1 - s_i) + q_i s_i + p_k (1 - s_k) + q_k s_k), \forall i,k \in \text{rectangles} $
#
# $\bar{x} \geq x \geq x^\prime_i + \frac{1}{2}(p_i s_i + q_i (1-s_i)), \forall i \in \text{rectangles} $
# $\bar{y} \geq y \geq y^\prime_i + \frac{1}{2}(p_i (1-s_i) + q_i s_i), \forall i \in \text{rectangles} $
# $x^\prime_i - \frac{1}{2}(p_i s_i + q_i (1-s_i)) \geq 0, \forall i \in \text{rectangles} $
# $y^\prime_i - \frac{1}{2}(p_i (1-s_i) + q_i s_i) \geq 0, \forall i \in \text{rectangles} $
#
#
#
#
# $s_i, u_{ik}, v_{ik}, \alpha^X_j, \alpha^Y_j \in \{0, 1\}, \text{else all varialbes} \geq 0$

# %% [markdown]
# ### (b)

# %%
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
import math
import numpy as np
P = [8] * 4 + [9] * 5 + [18] * 3
Q = [16] * 4 + [9] * 5 + [3] * 3
x_bar = 18 * 3 + 9 * 5 + 16 * 4
y_bar = 18 * 3 + 9 * 5 + 16 * 4

J = len(P)
m_X = 10
m_Y = 10

# %%
a = list()
ln_a = list()
for _ in np.linspace(3, x_bar, num=m_X):
    a.append(_)
    ln_a.append(math.log(_))

b = list()
ln_b = list()
for _ in np.linspace(3, y_bar, num=m_Y):
    b.append(_)
    ln_b.append(math.log(_))

t_X = list()
for j in range(0, m_X-1):
    t_X.append((ln_a[j+1] - ln_a[j]) / (a[j+1] - a[j]))

t_Y = list()
for j in range(0, m_Y-1):
    t_Y.append((ln_b[j+1] - ln_b[j]) / (b[j+1] - b[j]))

plt.scatter(a, ln_a)

# %%
model = gp.Model("cutting_stock")
model.setParam('TimeLimit', 5*60)
# Out:
# Using license file C:\Users\user\gurobi.lic
# Academic license - for non-commercial use only
# Changed value of parameter TimeLimit to 300.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf

# %%
x = model.addVar(lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="x")
y = model.addVar(lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="y")
x_prime = model.addVars(J, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="x_prime")
y_prime = model.addVars(J, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="y_prime")
s = model.addVars(J, vtype=GRB.BINARY, name="s")
u = model.addVars(J, J, vtype=GRB.BINARY, name="u")
v = model.addVars(J, J, vtype=GRB.BINARY, name="v")
alpha_X = model.addVars(m_X, lb=0.0, ub=1.0, vtype=GRB.BINARY, name="alpha_X")
alpha_Y = model.addVars(m_Y, lb=0.0, ub=1.0, vtype=GRB.BINARY, name="alpha_Y")
beta_X = model.addVars(m_X, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="beta_X")
beta_Y = model.addVars(m_Y, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="beta_Y")

# %%
model.setObjective(
    ln_a[0] + t_X[0] * (x - a[0]) + \
    gp.quicksum((t_X[j] - t_X[j-1]) * (a[j] * alpha_X[j] + x - a[j] - beta_X[j]) for j in range(1, m_X-1)) + \
    ln_b[0] + t_Y[0] * (y - b[0]) + \
    gp.quicksum((t_Y[j] - t_Y[j-1]) * (b[j] * alpha_Y[j] + y - b[j] - beta_Y[j]) for j in range(1, m_Y-1))
)

# %%
model.addConstrs(-x_bar * alpha_X[j] <= x - a[j] for j in range(1, m_X))
model.addConstrs(x - a[j] <= x_bar * (1 - alpha_X[j]) for j in range(1, m_X))
model.addConstrs(-x_bar * alpha_X[j] <= beta_X[j] for j in range(1, m_X))
model.addConstrs(beta_X[j] <= x_bar * alpha_X[j] for j in range(1, m_X))
model.addConstrs(x_bar * (alpha_X[j] - 1) + x <= beta_X[j] for j in range(1, m_X))
model.addConstrs(beta_X[j] <= x_bar * (1 - alpha_X[j]) + x for j in range(1, m_X))
model.addConstrs(alpha_X[j] >= alpha_X[j-1] for j in range(1, m_X))



model.addConstrs(-y_bar * alpha_Y[j] <= y - b[j] for j in range(1, m_Y))
model.addConstrs(y - b[j] <= y_bar * (1 - alpha_Y[j]) for j in range(1, m_Y))
model.addConstrs(-y_bar * alpha_Y[j] <= beta_Y[j] for j in range(1, m_Y))
model.addConstrs(beta_Y[j] <= y_bar * alpha_Y[j] for j in range(1, m_Y))
model.addConstrs(y_bar * (alpha_Y[j] - 1) + y <= beta_Y[j] for j in range(1, m_Y))
model.addConstrs(beta_Y[j] <= y_bar * (1 - alpha_Y[j]) + y for j in range(1, m_Y))
model.addConstrs(alpha_Y[j] >= alpha_Y[j-1] for j in range(1, m_Y))




model.addConstrs(
    (x_prime[i] - x_prime[k]) + u[i,k] * x_bar + v[i,k] * x_bar >= \
    0.5 * (P[i] * s[i] + Q[i] * (1 - s[i]) + P[k] * s[k] + Q[k] * (1 - s[k])) \
    for i in range(J) for k in range(J) if i != k
    )


model.addConstrs(
    (x_prime[k] - x_prime[i]) + (1 - u[i,k]) * x_bar + v[i,k] * x_bar >= \
    0.5 * (P[i] * s[i] + Q[i] * (1 - s[i]) + P[k] * s[k] + Q[k] * (1 - s[k])) \
    for i in range(J) for k in range(J) if i != k
    )

model.addConstrs(
    (y_prime[i] - y_prime[k]) + u[i,k] * y_bar + (1 - v[i,k]) * y_bar >= \
    0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i] + P[k] * (1 - s[k]) + Q[k] * s[k]) \
    for i in range(J) for k in range(J) if i != k
    )

model.addConstrs(
    (y_prime[k] - y_prime[i]) + (1 - u[i,k]) * y_bar + (1 - v[i,k]) * y_bar >= \
    0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i] + P[k] * (1 - s[k]) + Q[k] * s[k]) \
    for i in range(J) for k in range(J) if i != k
    )

model.addConstr(x_bar >= x)
model.addConstrs(x >= x_prime[i] + 0.5 * (P[i] * s[i] + Q[i] * (1 - s[i])) for i in range(J))
model.addConstr(y_bar >= y)
model.addConstrs(y >= y_prime[i] + 0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i]) for i in range(J))

model.addConstrs(x_prime[i] - 0.5 * (P[i] * s[i] + Q[i] * (1 - s[i])) >= 0 for i in range(J))
model.addConstrs(y_prime[i] - 0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i]) >= 0 for i in range(J))
# Out:
# {0: <gurobi.Constr *Awaiting Model Update*>,
#  1: <gurobi.Constr *Awaiting Model Update*>,
#  2: <gurobi.Constr *Awaiting Model Update*>,
#  3: <gurobi.Constr *Awaiting Model Update*>,
#  4: <gurobi.Constr *Awaiting Model Update*>,
#  5: <gurobi.Constr *Awaiting Model Update*>,
#  6: <gurobi.Constr *Awaiting Model Update*>,
#  7: <gurobi.Constr *Awaiting Model Update*>,
#  8: <gurobi.Constr *Awaiting Model Update*>,
#  9: <gurobi.Constr *Awaiting Model Update*>,
#  10: <gurobi.Constr *Awaiting Model Update*>,
#  11: <gurobi.Constr *Awaiting Model Update*>}

# %%
model.write('q3.lp')

model.optimize()
# Out:
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 704 rows, 366 columns and 3118 nonzeros
# Model fingerprint: 0x76d6e780
# Variable types: 46 continuous, 320 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [8e-04, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 8.6111309
# Presolve removed 44 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 660 rows, 329 columns, 3094 nonzeros
# Variable types: 42 continuous, 287 integer (287 binary)
#
# Root relaxation: objective 2.234054e+00, 190 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.23405    0  153    8.61113    2.23405  74.1%     -    0s
# H    0     0                       7.2674699    2.23405  69.3%     -    0s
# H    0     0                       7.2405791    2.23405  69.1%     -    0s
# H    0     0                       7.1756740    2.23405  68.9%     -    0s
#      0     0    4.48326    0  236    7.17567    4.48326  37.5%     -    0s
#      0     0    4.48326    0  154    7.17567    4.48326  37.5%     -    0s
#      0     2    4.48326    0  132    7.17567    4.48326  37.5%     -    0s
# H  517   401                       7.1330156    4.48326  37.1%  18.6    0s
# H  974   675                       7.1116864    4.70098  33.9%  17.1    1s
# H  998   675                       7.0690279    4.70098  33.5%  16.8    1s
#   5811  2524    5.49910   63  106    7.06903    5.45619  22.8%  20.0    5s
# * 6888  3044              87       7.0353491    5.46218  22.4%  21.9    5s
# H 7610  3342                       7.0199209    5.46544  22.1%  22.9    5s
# H 7684  3251                       6.8339208    5.46544  20.0%  23.1    6s
#  14131  6085    6.60858   70   26    6.83392    5.50859  19.4%  27.6   10s
#  25437  9812    6.26068   67   71    6.83392    5.62224  17.7%  31.9   15s
#  29190 10586    6.56150   68  154    6.83392    5.65220  17.3%  32.7   20s
#  29232 10611    6.59945   51   47    6.83392    5.65220  17.3%  33.2   25s
# *29778 10214              93       6.7283993    5.65220  16.0%  33.0   26s
# H32843 10060                       6.7283993    5.65220  16.0%  34.4   29s
#  33970 10215    6.43574   74   55    6.72840    5.65220  16.0%  34.6   30s
#  42335 10698     cutoff   76         6.72840    5.79621  13.9%  35.8   35s
# H46985  8060                       6.5956912    5.81896  11.8%  35.9   37s
#  50153  7236    6.39086   75   49    6.59569    5.85970  11.2%  36.6   40s
# H52087  6169                       6.5956912    5.91221  10.4%  37.8   44s
#  52162  6215 infeasible   63         6.59569    5.91221  10.4%  37.8   45s
#  58754  6804    6.13457   80   32    6.59569    6.05733  8.16%  38.3   50s
#  71885 10851     cutoff   77         6.59569    6.05942  8.13%  34.3   55s
#  83162 14035    6.57007   71   76    6.59569    6.06777  8.00%  33.8   60s
#  89804 15963    6.19260   78   39    6.59569    6.07188  7.94%  34.7   65s
#  102364 17042    6.11138   62   93    6.59569    6.10209  7.48%  32.9   70s
#  110245 17749    6.50052   82   44    6.59569    6.11196  7.33%  33.2   75s
#  118803 18213     cutoff   75         6.59569    6.14937  6.77%  33.1   80s
#  125630 19256    6.43097   72   58    6.59569    6.15816  6.63%  33.5   85s
#  131079 20190    6.34821   75   47    6.59569    6.16588  6.52%  34.4   90s
#  135886 21095 infeasible   78         6.59569    6.16588  6.52%  35.1   95s
#  141391 22094    6.32688   78   68    6.59569    6.16588  6.52%  35.9  100s
#  146266 22590 infeasible   75         6.59569    6.16993  6.46%  36.2  112s
# H146555 22590                       6.5956912    6.16993  6.46%  36.2  112s
#  149096 23027    6.20803   71   95    6.59569    6.16993  6.46%  36.5  115s
#  154117 23538     cutoff   69         6.59569    6.17982  6.31%  37.1  120s
#  157654 24366     cutoff   73         6.59569    6.17982  6.31%  38.1  125s
# H159631 24611                       6.5956912    6.17982  6.31%  38.6  127s
#  161401 24969    6.18621   68  116    6.59569    6.17982  6.31%  38.9  130s
#  165807 25774     cutoff   83         6.59569    6.18621  6.21%  39.8  136s
#  168875 26404    6.29826   73   83    6.59569    6.18621  6.21%  40.5  140s
#  173740 27359    6.33304   71   85    6.59569    6.18621  6.21%  41.5  145s
#  177773 28250     cutoff   75         6.59569    6.18621  6.21%  42.3  150s
#  181559 28927    6.18621   68   90    6.59569    6.18621  6.21%  43.1  155s
#  185772 29640    6.43097   79   65    6.59569    6.18621  6.21%  44.1  160s
#  190087 29915     cutoff   74         6.59569    6.18776  6.18%  44.6  165s
#  194927 30352    6.30555   71   76    6.59569    6.19669  6.05%  44.8  170s
#  199551 30489 infeasible   73         6.59569    6.19788  6.03%  45.1  175s
#  202428 31021 infeasible   72         6.59569    6.20361  5.94%  45.6  180s
#  206239 31779    6.36142   73   70    6.59569    6.20361  5.94%  46.4  185s
#  209610 32290    6.24937   77   80    6.59569    6.20361  5.94%  46.9  190s
#  214371 32622 infeasible   80         6.59569    6.21459  5.78%  47.2  195s
#  218488 33256     cutoff   75         6.59569    6.21459  5.78%  47.8  201s
#  221716 33793    6.43097   73   82    6.59569    6.21459  5.78%  48.3  205s
#  225899 34503     cutoff   80         6.59569    6.21459  5.78%  49.1  211s
#  229520 35030    6.57007   75   58    6.59569    6.21459  5.78%  49.6  216s
#  232965 35449    6.43097   83   71    6.59569    6.21459  5.78%  50.1  220s
#  236580 36106     cutoff   73         6.59569    6.21459  5.78%  50.5  225s
# H237838 36106                       6.5956912    6.21459  5.78%  50.7  239s
#  237839 36107    6.32665   65  154    6.59569    6.21459  5.78%  50.7  240s
#  237872 36129    6.38391   64   90    6.59569    6.21459  5.78%  50.7  245s
# H237948 34365                       6.5956912    6.21459  5.78%  50.7  246s
#  241857 34812    6.21459   99   25    6.59569    6.21459  5.78%  50.7  250s
#  249530 33967     cutoff   83         6.59569    6.21459  5.78%  50.5  255s
# H250943 31879                       6.5956912    6.21459  5.78%  50.4  256s
#  257056 30259    6.21459   81   40    6.59569    6.21459  5.78%  50.3  260s
#  267158 27735    6.21459   79   37    6.59569    6.21459  5.78%  49.9  265s
#  281768 27727    6.32347   91   33    6.59569    6.21459  5.78%  48.3  270s
#  299536 26517    6.52757   84   63    6.59569    6.21459  5.78%  46.4  275s
#  307279 25365    6.46574   87   31    6.59569    6.21459  5.78%  45.6  282s
#  314415 23750    6.35798  102   17    6.59569    6.21459  5.78%  45.1  285s
#  323316 21501 infeasible   89         6.59569    6.21459  5.78%  44.9  290s
#  333714 17859    6.21459   99   38    6.59569    6.21459  5.78%  44.4  295s
#  342175 18219    6.30555   82   36    6.59569    6.21459  5.78%  44.1  300s
#
# Cutting planes:
#   Learned: 9
#   Gomory: 153
#   Cover: 46
#   Implied bound: 5
#   Projected implied bound: 2
#   MIR: 405
#   Flow cover: 1062
#   GUB cover: 3
#   Inf proof: 76
#   Zero half: 16
#   RLT: 31
#   Relax-and-lift: 40
#
# Explored 342753 nodes (15152954 simplex iterations) in 300.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.59569 6.59569 6.59569 ... 6.83392
#
# Time limit reached
# Best objective 6.595691159835e+00, best bound 6.214594417771e+00, gap 5.7780%

# %% [markdown]
# ### (c)

# %%
from matplotlib.patches import Rectangle
fig, ax = plt.subplots()
colors = ['yellow', 'red', 'blue', 'green', 'pink', 'purple']
xs = list()
ys = list()
for j in range(J):
    center_x, center_y = model.getAttr('x', x_prime)[j], model.getAttr('x', y_prime)[j]
    print(center_x, center_y)
    xs.append(center_x)
    ys.append(center_y)
    if model.getAttr('x', s)[j] == 1: # p和x平行
        corner_x = center_x - 0.5 * P[j]
        corner_y = center_y - 0.5 * Q[j]
        ax.add_patch(Rectangle((corner_x, corner_y), P[j], Q[j], color=colors[j%len(colors)]))
    else: # p和y平行
        corner_x = center_x - 0.5 * Q[j]
        corner_y = center_y - 0.5 * P[j]
        ax.add_patch(Rectangle((corner_x, corner_y), Q[j], P[j], color=colors[j%len(colors)]))
    # break
ax.scatter(xs, ys, c='black', zorder=100)
# Out:
# 4.999999999999999 57.999999101175035
# 4.0 8.0
# 4.0 118.99999910117471
# 4.0 32.99999910117508
# 4.5 20.4999991011751
# 4.5 106.49999910117481
# 4.5 70.49999910117502
# 4.5 79.49999910117498
# 4.5 45.49999910117506
# 1.5 92.99999910117494
# 4.500000000000002 92.9999991011749
# 7.499999999999984 92.99999910117486

# %% [markdown]
# ### (d)

# %%
import gurobipy as gp
from gurobipy import GRB
import matplotlib.pyplot as plt
import math
import numpy as np
import time

# %%
def q3_4(resolution=10, n1=4, n2=5, n3=3, timelimit=3*60, gap=0.04, limit="time"):
    start = time.time()
    P = [8] * n1 + [9] * n2 + [18] * n3
    Q = [16] * n1 + [9] * n2 + [3] * n3
    x_bar = 16 * n1 + 9 * n2 + 18 * n3
    y_bar = 16 * n1 + 9 * n2 + 18 * n3

    J = len(P)
    m_X = resolution
    m_Y = resolution

    a = list()
    ln_a = list()
    for _ in np.linspace(3, x_bar, num=m_X):
        a.append(_)
        ln_a.append(math.log(_))

    b = list()
    ln_b = list()
    for _ in np.linspace(3, y_bar, num=m_Y):
        b.append(_)
        ln_b.append(math.log(_))

    t_X = list()
    for j in range(0, m_X-1):
        t_X.append((ln_a[j+1] - ln_a[j]) / (a[j+1] - a[j]))

    t_Y = list()
    for j in range(0, m_Y-1):
        t_Y.append((ln_b[j+1] - ln_b[j]) / (b[j+1] - b[j]))


    model = gp.Model("cutting_stock")
    if limit == "time":
        model.setParam('TimeLimit', timelimit)
    elif limit == "gap":
        model.setParam('MIPGap', gap)

    x = model.addVar(lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="x")
    y = model.addVar(lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="y")
    x_prime = model.addVars(J, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="x_prime")
    y_prime = model.addVars(J, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="y_prime")
    s = model.addVars(J, vtype=GRB.BINARY, name="s")
    u = model.addVars(J, J, vtype=GRB.BINARY, name="u")
    v = model.addVars(J, J, vtype=GRB.BINARY, name="v")
    alpha_X = model.addVars(m_X, lb=0.0, ub=1.0, vtype=GRB.BINARY, name="alpha_X")
    alpha_Y = model.addVars(m_Y, lb=0.0, ub=1.0, vtype=GRB.BINARY, name="alpha_Y")
    beta_X = model.addVars(m_X, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="beta_X")
    beta_Y = model.addVars(m_Y, lb=0.0, ub=float('inf'), vtype=GRB.CONTINUOUS, name="beta_Y")

    model.setObjective(
        ln_a[0] + t_X[0] * (x - a[0]) + \
        gp.quicksum((t_X[j] - t_X[j-1]) * (a[j] * alpha_X[j] + x - a[j] - beta_X[j]) for j in range(1, m_X-1)) + \
        ln_b[0] + t_Y[0] * (y - b[0]) + \
        gp.quicksum((t_Y[j] - t_Y[j-1]) * (b[j] * alpha_Y[j] + y - b[j] - beta_Y[j]) for j in range(1, m_Y-1))
    )

    model.addConstrs(-x_bar * alpha_X[j] <= x - a[j] for j in range(1, m_X))
    model.addConstrs(x - a[j] <= x_bar * (1 - alpha_X[j]) for j in range(1, m_X))
    model.addConstrs(-x_bar * alpha_X[j] <= beta_X[j] for j in range(1, m_X))
    model.addConstrs(beta_X[j] <= x_bar * alpha_X[j] for j in range(1, m_X))
    model.addConstrs(x_bar * (alpha_X[j] - 1) + x <= beta_X[j] for j in range(1, m_X))
    model.addConstrs(beta_X[j] <= x_bar * (1 - alpha_X[j]) + x for j in range(1, m_X))
    model.addConstrs(alpha_X[j] >= alpha_X[j-1] for j in range(1, m_X))



    model.addConstrs(-y_bar * alpha_Y[j] <= y - b[j] for j in range(1, m_Y))
    model.addConstrs(y - b[j] <= y_bar * (1 - alpha_Y[j]) for j in range(1, m_Y))
    model.addConstrs(-y_bar * alpha_Y[j] <= beta_Y[j] for j in range(1, m_Y))
    model.addConstrs(beta_Y[j] <= y_bar * alpha_Y[j] for j in range(1, m_Y))
    model.addConstrs(y_bar * (alpha_Y[j] - 1) + y <= beta_Y[j] for j in range(1, m_Y))
    model.addConstrs(beta_Y[j] <= y_bar * (1 - alpha_Y[j]) + y for j in range(1, m_Y))
    model.addConstrs(alpha_Y[j] >= alpha_Y[j-1] for j in range(1, m_Y))




    model.addConstrs(
        (x_prime[i] - x_prime[k]) + u[i,k] * x_bar + v[i,k] * x_bar >= \
        0.5 * (P[i] * s[i] + Q[i] * (1 - s[i]) + P[k] * s[k] + Q[k] * (1 - s[k])) \
        for i in range(J) for k in range(J) if i != k
        )


    model.addConstrs(
        (x_prime[k] - x_prime[i]) + (1 - u[i,k]) * x_bar + v[i,k] * x_bar >= \
        0.5 * (P[i] * s[i] + Q[i] * (1 - s[i]) + P[k] * s[k] + Q[k] * (1 - s[k])) \
        for i in range(J) for k in range(J) if i != k
        )

    model.addConstrs(
        (y_prime[i] - y_prime[k]) + u[i,k] * y_bar + (1 - v[i,k]) * y_bar >= \
        0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i] + P[k] * (1 - s[k]) + Q[k] * s[k]) \
        for i in range(J) for k in range(J) if i != k
        )

    model.addConstrs(
        (y_prime[k] - y_prime[i]) + (1 - u[i,k]) * y_bar + (1 - v[i,k]) * y_bar >= \
        0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i] + P[k] * (1 - s[k]) + Q[k] * s[k]) \
        for i in range(J) for k in range(J) if i != k
        )

    model.addConstr(x_bar >= x)
    model.addConstrs(x >= x_prime[i] + 0.5 * (P[i] * s[i] + Q[i] * (1 - s[i])) for i in range(J))
    model.addConstr(y_bar >= y)
    model.addConstrs(y >= y_prime[i] + 0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i]) for i in range(J))

    model.addConstrs(x_prime[i] - 0.5 * (P[i] * s[i] + Q[i] * (1 - s[i])) >= 0 for i in range(J))
    model.addConstrs(y_prime[i] - 0.5 * (P[i] * (1 - s[i]) + Q[i] * s[i]) >= 0 for i in range(J))

    model.optimize()
    # print("objective value:", model.objVal)
    if limit == "time":
        return model.objVal, model.MIPGap
    elif limit == "gap":
        return time.time() - start

# %%
objs = list()
gaps = list()
for resolution in range(10, 20, 2):
    obj, gap = q3_4(resolution=resolution, limit="time")
    objs.append(obj)
    gaps.append(gap)
# Out:
# Changed value of parameter TimeLimit to 180.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 704 rows, 366 columns and 3118 nonzeros
# Model fingerprint: 0x76d6e780
# Variable types: 46 continuous, 320 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [8e-04, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 8.6111309
# Presolve removed 44 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 660 rows, 329 columns, 3094 nonzeros
# Variable types: 42 continuous, 287 integer (287 binary)
#
# Root relaxation: objective 2.234054e+00, 190 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.23405    0  153    8.61113    2.23405  74.1%     -    0s
# H    0     0                       7.2674699    2.23405  69.3%     -    0s
# H    0     0                       7.2405791    2.23405  69.1%     -    0s
# H    0     0                       7.1756740    2.23405  68.9%     -    0s
#      0     0    4.48326    0  236    7.17567    4.48326  37.5%     -    0s
#      0     0    4.48326    0  154    7.17567    4.48326  37.5%     -    0s
#      0     2    4.48326    0  132    7.17567    4.48326  37.5%     -    0s
# H  517   401                       7.1330156    4.48326  37.1%  18.6    0s
# H  974   675                       7.1116864    4.70098  33.9%  17.1    1s
# H  998   675                       7.0690279    4.70098  33.5%  16.8    1s
#   5604  2391    6.27474   63   67    7.06903    5.45353  22.9%  19.4    5s
# * 6888  3044              87       7.0353491    5.46218  22.4%  21.9    5s
# H 7610  3342                       7.0199209    5.46544  22.1%  22.9    6s
# H 7684  3251                       6.8339208    5.46544  20.0%  23.1    6s
#  15324  6514    6.60637   61   48    6.83392    5.51661  19.3%  28.3   10s
#  26900 10131 infeasible   69         6.83392    5.62675  17.7%  32.3   15s
#  29193 10588    6.62770   69   66    6.83392    5.65220  17.3%  32.7   20s
# *29778 10214              93       6.7283993    5.65220  16.0%  33.0   24s
#  30058 10263 infeasible   60         6.72840    5.65220  16.0%  33.1   25s
# H32843 10060                       6.7283993    5.65220  16.0%  34.4   27s
#  36243 10236    6.36954   72   55    6.72840    5.67165  15.7%  35.7   30s
#  46032 10858 infeasible   75         6.72840    5.81423  13.6%  36.0   35s
# H46985  8060                       6.5956912    5.81896  11.8%  35.9   35s
#  52014  6649 infeasible   69         6.59569    5.91221  10.4%  37.8   42s
# H52087  6169                       6.5956912    5.91221  10.4%  37.8   42s
#  55943  5423    6.32665   61   69    6.59569    6.04019  8.42%  38.3   45s
#  69029 10046    6.09332   72   44    6.59569    6.05879  8.14%  35.2   50s
#  81795 13516    6.06777   64  103    6.59569    6.06777  8.00%  33.1   55s
#  86558 15140    6.32665   69   88    6.59569    6.06777  8.00%  35.1   60s
#  99440 16803    6.15315   74   38    6.59569    6.09600  7.58%  33.1   65s
#  108563 17530 infeasible   74         6.59569    6.11138  7.34%  32.9   70s
#  116130 17762     cutoff   72         6.59569    6.14404  6.85%  33.2   75s
#  124380 18923    6.16588   72   81    6.59569    6.15816  6.63%  33.2   80s
#  129687 19911 infeasible   75         6.59569    6.16363  6.55%  34.2   85s
#  134050 20777    6.16588   73   40    6.59569    6.16588  6.52%  34.9   90s
#  139778 21705    6.27474   68   80    6.59569    6.16588  6.52%  35.7   95s
#  146266 22590 infeasible   75         6.59569    6.16993  6.46%  36.2  107s
# H146555 22590                       6.5956912    6.16993  6.46%  36.2  107s
#  149899 23094    6.16993   71  101    6.59569    6.16993  6.46%  36.6  110s
#  155778 23909     cutoff   71         6.59569    6.17982  6.31%  37.6  115s
#  159597 24611     cutoff   73         6.59569    6.17982  6.31%  38.6  120s
# H159631 24611                       6.5956912    6.17982  6.31%  38.6  120s
#  163226 25251    6.52757   74   58    6.59569    6.18621  6.21%  39.2  125s
#  166735 26022    6.36142   77   66    6.59569    6.18621  6.21%  40.0  130s
#  170833 26687     cutoff   80         6.59569    6.18621  6.21%  40.9  135s
#  174622 27621 infeasible   84         6.59569    6.18621  6.21%  41.7  140s
#  178735 28424    6.39620   76   87    6.59569    6.18621  6.21%  42.5  146s
#  182434 29081    6.36142   69   68    6.59569    6.18621  6.21%  43.3  150s
#  185772 29640    6.43097   79   65    6.59569    6.18621  6.21%  44.1  155s
#  190087 29915     cutoff   74         6.59569    6.18776  6.18%  44.6  160s
#  194927 30352    6.30555   71   76    6.59569    6.19669  6.05%  44.8  165s
#  199551 30489 infeasible   73         6.59569    6.19788  6.03%  45.1  170s
#  203178 31211    6.20361   63   96    6.59569    6.20361  5.94%  45.8  175s
#  206945 31848 infeasible   67         6.59569    6.20361  5.94%  46.5  180s
#
# Cutting planes:
#   Learned: 17
#   Gomory: 149
#   Cover: 78
#   Implied bound: 3
#   Projected implied bound: 2
#   MIR: 454
#   Flow cover: 1179
#   Inf proof: 79
#   Zero half: 17
#   RLT: 51
#   Relax-and-lift: 27
#
# Explored 207211 nodes (9685222 simplex iterations) in 180.05 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.59569 6.59569 6.59569 ... 7.06903
#
# Time limit reached
# Best objective 6.595691165152e+00, best bound 6.203614999094e+00, gap 5.9444%
# Changed value of parameter TimeLimit to 180.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 732 rows, 374 columns and 3182 nonzeros
# Model fingerprint: 0xe03b5e5d
# Variable types: 50 continuous, 324 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [7e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 7.9475706
# Presolve removed 48 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 684 rows, 337 columns, 3166 nonzeros
# Variable types: 46 continuous, 291 integer (291 binary)
#
# Root relaxation: objective 2.160798e+00, 188 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.16080    0  157    7.94757    2.16080  72.8%     -    0s
# H    0     0                       7.9036334    2.16080  72.7%     -    0s
# H    0     0                       7.2922630    2.16080  70.4%     -    0s
#      0     0    4.71083    0  180    7.29226    4.71083  35.4%     -    0s
#      0     0    4.71083    0  136    7.29226    4.71083  35.4%     -    0s
#      0     2    4.71083    0  131    7.29226    4.71083  35.4%     -    0s
# H  333   285                       7.2665637    4.71083  35.2%  16.9    0s
# H 3220  1377                       7.2225817    5.07510  29.7%  11.3    2s
# H 3226  1312                       7.2016683    5.13962  28.6%  11.3    2s
# H 3248  1261                       7.1955528    5.39620  25.0%  14.5    4s
# H 3384  1275                       7.1041680    5.48244  22.8%  16.4    4s
# H 3403  1210                       6.9903687    5.48244  21.6%  16.4    4s
# H 3427  1159                       6.9646694    5.48244  21.3%  16.5    4s
#   3635  1199    6.24617   41   99    6.96467    5.56141  20.1%  17.2    5s
#  10817  3032 infeasible   57         6.96467    5.76733  17.2%  29.9   10s
#  14954  4611    6.68054   61  131    6.96467    5.76965  17.2%  32.3   15s
# H15151  4485                       6.9283659    5.76965  16.7%  32.8   15s
# H15210  4294                       6.8988927    5.76965  16.4%  32.7   16s
# H15219  4083                       6.7953354    5.76965  15.1%  32.7   16s
#  22729  4166    6.64094   79   31    6.79534    5.86796  13.6%  35.1   20s
#  28633  4360    6.79099   68   24    6.79534    5.94101  12.6%  36.5   25s
#  36341  6733    6.75076   80   27    6.79534    5.94829  12.5%  36.1   30s
#  43353  7903 infeasible   95         6.79534    5.99752  11.7%  36.7   35s
#  44710  8030    6.05917   79  136    6.79534    6.00970  11.6%  37.0   49s
#  44724  8039    6.50208   72  136    6.79534    6.00970  11.6%  37.0   50s
# H44755  7656                       6.7774676    6.00970  11.3%  36.9   54s
#  44757  7657    6.43148   75  125    6.77747    6.00970  11.3%  36.9   55s
#  44788  7678    6.46483   71  110    6.77747    6.00970  11.3%  36.9   60s
#  44818  7698    6.33235   65  114    6.77747    6.00970  11.3%  36.9   65s
#  44845  7716    6.70372   73  157    6.77747    6.00970  11.3%  36.9   70s
#  44875  7736    6.70372   66  140    6.77747    6.00970  11.3%  36.8   75s
#  44906  7757    6.64094   75   94    6.77747    6.00970  11.3%  36.8   80s
#  46286  7940    6.64094   80   61    6.77747    6.00970  11.3%  39.9   85s
#  48296  7694    6.73338   81   45    6.77747    6.00970  11.3%  40.4   90s
#  53860  7325    6.05789   76   98    6.77747    6.00970  11.3%  41.3   95s
# H57578  6271                       6.7774676    6.03883  10.9%  42.1   99s
#  58208  6135    6.14091   72   90    6.77747    6.03903  10.9%  42.6  100s
#  61940  5276 infeasible   77         6.77747    6.09033  10.1%  44.3  105s
#  66438  5168    6.77489   88   44    6.77747    6.14571  9.32%  44.9  110s
#  76447  8003    6.51858   93   33    6.77747    6.15430  9.19%  42.5  115s
#  86400 10257     cutoff   94         6.77747    6.16063  9.10%  40.1  120s
#  94465 11201 infeasible   82         6.77747    6.18242  8.78%  38.9  125s
#  102177 11974    6.64280   74   70    6.77747    6.21653  8.28%  38.2  130s
#  112323 12992    6.49708   89   26    6.77747    6.25423  7.72%  36.6  135s
#  122913 13385    6.29598   89   33    6.77747    6.26544  7.55%  35.0  140s
#  128268 13138 infeasible   82         6.77747    6.28384  7.28%  35.8  145s
#  131900 13111    6.34846   80   76    6.77747    6.30695  6.94%  36.6  150s
#  134668 13234    6.63903   81   70    6.77747    6.30695  6.94%  38.3  155s
#  137841 13223    6.63903   88   46    6.77747    6.31104  6.88%  39.3  166s
#  139940 13348    6.63903   81   96    6.77747    6.32959  6.61%  40.1  170s
#  141970 13528    6.50473   90   54    6.77747    6.32959  6.61%  41.5  175s
#
# Cutting planes:
#   Learned: 19
#   Gomory: 181
#   Cover: 29
#   Implied bound: 10
#   MIR: 502
#   Flow cover: 1109
#   GUB cover: 4
#   Inf proof: 50
#   Zero half: 4
#   RLT: 49
#   Relax-and-lift: 73
#
# Explored 144684 nodes (6218130 simplex iterations) in 180.02 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.77747 6.77747 6.79534 ... 7.20167
#
# Time limit reached
# Best objective 6.777467605916e+00, best bound 6.329594088566e+00, gap 6.6083%
# Changed value of parameter TimeLimit to 180.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 760 rows, 382 columns and 3246 nonzeros
# Model fingerprint: 0xac59cb3f
# Variable types: 54 continuous, 328 integer (328 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [5e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 7.9113435
# Presolve removed 52 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 708 rows, 345 columns, 3238 nonzeros
# Variable types: 50 continuous, 295 integer (295 binary)
#
# Root relaxation: objective 2.100159e+00, 187 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.10016    0  161    7.91134    2.10016  73.5%     -    0s
# H    0     0                       7.2936558    2.10016  71.2%     -    0s
# H    0     0                       7.2287801    2.10016  70.9%     -    0s
#      0     0    5.21149    0  207    7.22878    5.21149  27.9%     -    0s
#      0     0    5.21149    0  147    7.22878    5.21149  27.9%     -    0s
#      0     2    5.21149    0  135    7.22878    5.21149  27.9%     -    0s
# H 3145  1523                       7.1657528    5.21149  27.3%  15.7    2s
# H 3461  1605                       7.1576388    5.62367  21.4%  18.2    3s
# H 3462  1532                       7.1248596    5.62367  21.1%  18.2    4s
#   4976  1892    6.85789   65   31    7.12486    5.67902  20.3%  21.5    5s
# H 4983  1819                       7.1076679    5.67902  20.1%  21.6    5s
# H 7561  2343                       7.0790439    5.67902  19.8%  25.1    6s
#  14959  5924    6.60077   71   37    7.07904    5.69252  19.6%  29.2   10s
# *18600  7422              85       7.0490966    5.70287  19.1%  30.3   11s
#  26712 11972    6.95925   81   26    7.04910    5.70905  19.0%  30.2   15s
#  29074 12742    6.17579   60  147    7.04910    5.70999  19.0%  30.2   21s
#  29102 12761    6.30710   62   80    7.04910    5.70999  19.0%  30.2   25s
#  29141 12787    6.06253   55   87    7.04910    5.71484  18.9%  30.2   30s
#  29175 12809    6.52323   65   42    7.04910    5.71484  18.9%  30.1   35s
#  31469 13404    5.75873   66  113    7.04910    5.71484  18.9%  32.2   41s
# *33310 13015              94       7.0430060    5.74001  18.5%  33.4   42s
#  36328 13603    6.20443   77   84    7.04301    5.78659  17.8%  35.4   45s
# *37508 12953              97       6.9950671    5.80352  17.0%  36.2   45s
#  43768 13616 infeasible   75         6.99507    5.90305  15.6%  39.4   50s
#  51437 13913 infeasible   71         6.99507    6.02099  13.9%  42.6   55s
#  59438 15418    6.72056   77   43    6.99507    6.08426  13.0%  42.8   60s
#  67521 17301     cutoff   78         6.99507    6.10206  12.8%  43.4   65s
#  76110 21016    6.70257   79   38    6.99507    6.12786  12.4%  44.1   70s
#  81897 22918 infeasible   75         6.99507    6.13937  12.2%  45.2   75s
#  87995 25130    6.62468   73   45    6.99507    6.15751  12.0%  46.0   80s
#  97003 28917 infeasible   82         6.99507    6.17579  11.7%  45.6   85s
#  104659 31574    6.92789   77   37    6.99507    6.17579  11.7%  45.5   90s
#  112604 34941    6.72056   74   38    6.99507    6.17579  11.7%  45.6   95s
#  119753 37924     cutoff  105         6.99507    6.17579  11.7%  46.1  100s
#  126340 40547 infeasible   83         6.99507    6.17579  11.7%  46.5  105s
#  133049 43472     cutoff   90         6.99507    6.17579  11.7%  46.9  110s
#  139173 46146    6.63675   71   65    6.99507    6.17579  11.7%  47.1  115s
#  145122 48794    6.63072   75   60    6.99507    6.17579  11.7%  47.3  120s
#  149071 49857    6.63675   75   56    6.99507    6.17579  11.7%  47.3  126s
#  153885 52348    6.58554   72   40    6.99507    6.17579  11.7%  47.4  130s
#  160021 54872    6.17579   70   76    6.99507    6.17579  11.7%  47.5  135s
#  166529 57537    6.25219   70   80    6.99507    6.17579  11.7%  47.5  140s
#  172491 59950 infeasible   83         6.99507    6.17579  11.7%  47.5  145s
#  179808 62855    6.88784   97   27    6.99507    6.17579  11.7%  47.5  150s
#  185418 65072    6.63675   71   70    6.99507    6.17579  11.7%  47.6  155s
#  192720 68240    6.63675   74   61    6.99507    6.17579  11.7%  47.8  160s
#  198877 70528    6.98920   79   36    6.99507    6.17579  11.7%  47.8  165s
#  205929 73468    6.92931   82   31    6.99507    6.17579  11.7%  47.9  170s
#  210956 75400     cutoff   92         6.99507    6.17579  11.7%  47.9  175s
#  217269 77561    6.36794   83   57    6.99507    6.17579  11.7%  48.0  180s
#
# Cutting planes:
#   Learned: 13
#   Gomory: 173
#   Cover: 31
#   Implied bound: 20
#   MIR: 421
#   Flow cover: 1119
#   GUB cover: 1
#   Inf proof: 76
#   Zero half: 4
#   RLT: 45
#   Relax-and-lift: 34
#
# Explored 217591 nodes (10455760 simplex iterations) in 180.15 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.99507 7.04301 7.0491 ... 7.22878
#
# Time limit reached
# Best objective 6.995067062585e+00, best bound 6.175794840363e+00, gap 11.7121%
# Changed value of parameter TimeLimit to 180.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 788 rows, 390 columns and 3310 nonzeros
# Model fingerprint: 0x0b6d76c6
# Variable types: 58 continuous, 332 integer (332 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [5e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 7.7673760
# Presolve removed 56 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 732 rows, 353 columns, 3310 nonzeros
# Variable types: 54 continuous, 299 integer (299 binary)
#
# Root relaxation: objective 2.045987e+00, 184 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.04599    0  165    7.76738    2.04599  73.7%     -    0s
# H    0     0                       7.3832766    2.04599  72.3%     -    0s
# H    0     0                       7.3260122    2.04599  72.1%     -    0s
# H    0     0                       7.3102116    2.04599  72.0%     -    0s
# H    0     0                       7.1356356    2.04599  71.3%     -    0s
# H    0     0                       7.0766179    2.04599  71.1%     -    0s
#      0     0    5.40467    0  195    7.07662    5.40467  23.6%     -    0s
#      0     0    5.40467    0  135    7.07662    5.40467  23.6%     -    0s
#      0     2    5.40467    0  128    7.07662    5.40467  23.6%     -    0s
#   8119  4047    5.95689   61   87    7.07662    5.95689  15.8%  17.0    5s
# * 8857  4062              87       7.0425397    5.95901  15.4%  16.9    5s
# *14785  6974              85       7.0268119    6.00458  14.5%  18.1    7s
#  20143  8246    6.14197   52   36    7.02681    6.09940  13.2%  25.7   10s
# *21675  8503              73       7.0137797    6.13204  12.6%  25.5   10s
# *21693  7697              77       6.9999297    6.13204  12.4%  25.5   10s
# H30165 10434                       6.9836729    6.15625  11.8%  23.9   17s
#  30185 10448    6.26836   55   81    6.98367    6.15625  11.8%  23.9   20s
# H30190  9928                       6.9511592    6.15625  11.4%  23.8   21s
#  30216  9945    6.82652   66  113    6.95116    6.15625  11.4%  23.8   25s
#  33312 10317    6.15625   65  120    6.95116    6.15625  11.4%  28.3   30s
#  37557 10599    6.33348   71   72    6.95116    6.15625  11.4%  33.4   35s
#  43185 10643    6.40467   70   78    6.95116    6.15625  11.4%  38.7   40s
#  47331 10951    6.77244   66   59    6.95116    6.15625  11.4%  40.7   45s
#  49432 10968    6.91822   88   15    6.95116    6.15625  11.4%  41.7   50s
#  55228 10990    6.76991   78   51    6.95116    6.22528  10.4%  43.5   55s
#  62426 12009    6.77914   74   45    6.95116    6.28486  9.59%  44.4   60s
#  67749 13559 infeasible   92         6.95116    6.29650  9.42%  45.7   65s
#  73363 15067    6.44049   71   64    6.95116    6.32019  9.08%  46.4   70s
#  79958 17829    6.67069   85   47    6.95116    6.32885  8.95%  46.0   75s
#  86424 19606    6.61661   81   47    6.95116    6.34926  8.66%  46.5   80s
#  92387 21354    6.74124   78   34    6.95116    6.35059  8.64%  46.8   85s
#  98210 23094 infeasible   85         6.95116    6.35059  8.64%  47.5   90s
#  104238 24941    6.47457   69   63    6.95116    6.36799  8.39%  47.8   95s
#  111384 26745    6.46321   75   57    6.95116    6.38276  8.18%  47.8  100s
#  117282 29609    6.44049   72   55    6.95116    6.38369  8.16%  47.5  105s
#  124610 32745    6.74720   91   34    6.95116    6.38369  8.16%  47.1  110s
#  132977 36365    6.42643   73   66    6.95116    6.38369  8.16%  46.6  115s
#  141011 39518    6.88061   67   55    6.95116    6.38369  8.16%  45.8  120s
#  149156 42866 infeasible   97         6.95116    6.38369  8.16%  45.4  125s
#  156051 46009    6.40641   78   60    6.95116    6.38369  8.16%  45.2  130s
#  158315 46524    6.44049   74   62    6.95116    6.38369  8.16%  45.1  135s
#  163701 48908    6.91955   82   45    6.95116    6.38369  8.16%  45.0  140s
#  169458 51295     cutoff   83         6.95116    6.38369  8.16%  45.1  145s
#  176550 54191     cutoff   87         6.95116    6.38369  8.16%  45.0  150s
#  183739 57286    6.73584   85   45    6.95116    6.38369  8.16%  44.7  155s
#  190702 59914     cutoff   86         6.95116    6.38369  8.16%  44.6  160s
#  199917 63478    6.74720   78   65    6.95116    6.38553  8.14%  44.4  165s
#  206986 65733    6.69680   71   41    6.95116    6.39057  8.06%  44.2  170s
#  214382 68484    6.45759   75   67    6.95116    6.39224  8.04%  43.9  175s
#  220634 70342    6.72917   79   40    6.95116    6.39269  8.03%  43.9  180s
#
# Cutting planes:
#   Learned: 12
#   Gomory: 172
#   Cover: 36
#   Implied bound: 20
#   Projected implied bound: 1
#   MIR: 493
#   StrongCG: 2
#   Flow cover: 1216
#   GUB cover: 9
#   Inf proof: 119
#   Zero half: 2
#   RLT: 40
#   Relax-and-lift: 41
#
# Explored 221367 nodes (9762624 simplex iterations) in 180.07 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.95116 6.98367 6.99993 ... 7.31021
#
# Time limit reached
# Best objective 6.951159210121e+00, best bound 6.392834153850e+00, gap 8.0321%
# Changed value of parameter TimeLimit to 180.0
#    Prev: inf  Min: 0.0  Max: inf  Default: inf
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 816 rows, 398 columns and 3374 nonzeros
# Model fingerprint: 0xb9614dac
# Variable types: 62 continuous, 336 integer (336 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [4e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 8.4459543
# Presolve removed 60 rows and 37 columns
# Presolve time: 0.04s
# Presolved: 756 rows, 361 columns, 3382 nonzeros
# Variable types: 58 continuous, 303 integer (303 binary)
#
# Root relaxation: objective 1.995949e+00, 190 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    1.99595    0  169    8.44595    1.99595  76.4%     -    0s
# H    0     0                       7.4145390    1.99595  73.1%     -    0s
# H    0     0                       7.1777513    1.99595  72.2%     -    0s
#      0     0    5.37237    0  203    7.17775    5.37237  25.2%     -    0s
#      0     0    5.37237    0  140    7.17775    5.37237  25.2%     -    0s
#      0     2    5.37237    0  134    7.17775    5.37237  25.2%     -    0s
# H 1055   619                       7.1497674    5.37237  24.9%  16.5    0s
# * 4569  1762              84       7.1194039    5.83021  18.1%  12.0    4s
#   4643  1770 infeasible   50         7.11940    5.87569  17.5%  12.4    5s
# * 5171  1781              81       7.1104763    5.99442  15.7%  14.3    5s
# H 5199  1675                       7.0432099    5.99442  14.9%  14.4    5s
# *11975  4323              96       7.0212232    6.16598  12.2%  24.5    9s
#  13368  5207 infeasible   79         7.02122    6.16598  12.2%  24.5   10s
# H18801  7476                       7.0212232    6.16598  12.2%  25.7   13s
#  23214  9896 infeasible   59         7.02122    6.16598  12.2%  26.2   15s
# H24354 10275                       7.0150623    6.16598  12.1%  26.2   15s
#  29144 12224    6.70505   63  140    7.01506    6.16598  12.1%  27.2   24s
#  29152 12229    6.53466   59   88    7.01506    6.16598  12.1%  27.2   25s
#  29196 12259    6.82710   75  100    7.01506    6.16598  12.1%  27.2   30s
#  32067 12898    6.99619   83   33    7.01506    6.16598  12.1%  30.9   35s
#  34603 13239    6.16598   61  102    7.01506    6.16598  12.1%  34.7   40s
#  37928 13414    6.43873   62   70    7.01506    6.16598  12.1%  39.4   45s
# *42091 12979              86       6.9804543    6.16598  11.7%  41.8   49s
#  42141 12962    6.52454   64   91    6.98045    6.16598  11.7%  41.8   52s
#  42154 12961    6.52454   66   84    6.98045    6.16598  11.7%  41.8   57s
#  43358 13268    6.52454   70   48    6.98045    6.16598  11.7%  42.8   60s
#  46639 13723 infeasible   66         6.98045    6.16598  11.7%  44.6   65s
#  50694 14312     cutoff   80         6.98045    6.16598  11.7%  46.1   70s
#  54510 14375    6.24889   65   80    6.98045    6.16598  11.7%  47.9   75s
#  58063 14565 infeasible   65         6.98045    6.21011  11.0%  49.5   80s
#  60809 14890 infeasible   64         6.98045    6.22830  10.8%  50.6   85s
#  64868 15429    6.75104   73   37    6.98045    6.23628  10.7%  51.4   90s
#  68622 16689 infeasible   64         6.98045    6.24889  10.5%  51.6   95s
#  72157 18050    6.94703   79   28    6.98045    6.26570  10.2%  51.9  100s
#  75337 19495    6.34372   60   84    6.98045    6.28636  9.94%  52.3  105s
#  79715 21226 infeasible   66         6.98045    6.28699  9.93%  52.4  111s
#  83612 22339    6.28699   64   85    6.98045    6.28699  9.93%  52.5  116s
#  85284 22743    6.56039   66   60    6.98045    6.28699  9.93%  53.7  120s
#  89058 24303    6.52797   59   58    6.98045    6.29527  9.82%  53.9  125s
#  92882 25459    6.77113   76   28    6.98045    6.29527  9.82%  54.3  131s
#  95651 26334    6.29527   66   50    6.98045    6.29527  9.82%  54.5  135s
#  99852 27663    6.31274   70  103    6.98045    6.29527  9.82%  54.6  141s
#  102149 28357    6.80923   77   20    6.98045    6.29527  9.82%  55.0  145s
#  103831 28534    6.80323   72  140    6.98045    6.29527  9.82%  55.3  162s
#  103854 28549    6.97869   95   49    6.98045    6.29527  9.82%  55.3  165s
# H103871 27132                       6.8476858    6.29527  8.07%  55.3  168s
#  103884 27140    6.60190   68   67    6.84769    6.29527  8.07%  55.3  170s
#  105313 27196 infeasible   81         6.84769    6.29527  8.07%  55.6  175s
#
# Cutting planes:
#   Learned: 15
#   Gomory: 105
#   Cover: 29
#   Implied bound: 10
#   MIR: 213
#   Flow cover: 777
#   GUB cover: 13
#   Inf proof: 28
#   Zero half: 8
#   RLT: 51
#   Relax-and-lift: 26
#
# Explored 109891 nodes (6140179 simplex iterations) in 180.06 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.84769 6.98045 7.01506 ... 7.14977
#
# Time limit reached
# Best objective 6.847685779752e+00, best bound 6.295272674527e+00, gap 8.0672%

# %%
ts = list()
for resolution in range(10, 20, 2):
    t = q3_4(resolution=resolution, limit="gap")
    ts.append(t)
# Out:
# Changed value of parameter MIPGap to 0.04
#    Prev: 0.0001  Min: 0.0  Max: inf  Default: 0.0001
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 704 rows, 366 columns and 3118 nonzeros
# Model fingerprint: 0x76d6e780
# Variable types: 46 continuous, 320 integer (320 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [8e-04, 2e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 8.6111309
# Presolve removed 44 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 660 rows, 329 columns, 3094 nonzeros
# Variable types: 42 continuous, 287 integer (287 binary)
#
# Root relaxation: objective 2.234054e+00, 190 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.23405    0  153    8.61113    2.23405  74.1%     -    0s
# H    0     0                       7.2674699    2.23405  69.3%     -    0s
# H    0     0                       7.2405791    2.23405  69.1%     -    0s
# H    0     0                       7.1756740    2.23405  68.9%     -    0s
#      0     0    4.48326    0  236    7.17567    4.48326  37.5%     -    0s
#      0     0    4.48326    0  154    7.17567    4.48326  37.5%     -    0s
#      0     2    4.48326    0  132    7.17567    4.48326  37.5%     -    0s
# H  517   401                       7.1330156    4.48326  37.1%  18.6    0s
# H  974   675                       7.1116864    4.70098  33.9%  17.1    1s
# H  998   675                       7.0690279    4.70098  33.5%  16.8    1s
#   5384  2288    6.47839   72   48    7.06903    5.45005  22.9%  18.7    5s
# * 6888  3044              87       7.0353491    5.46218  22.4%  21.9    5s
# H 7610  3342                       7.0199209    5.46544  22.1%  22.9    6s
# H 7684  3251                       6.8339208    5.46544  20.0%  23.1    6s
#  14131  6085    6.60858   70   26    6.83392    5.50859  19.4%  27.6   10s
#  24632  9682    6.27474   63   56    6.83392    5.61502  17.8%  31.8   15s
#  29190 10586    6.56150   68  154    6.83392    5.65220  17.3%  32.7   20s
#  29257 10625    5.76538   54   87    6.83392    5.65220  17.3%  33.2   25s
# *29778 10214              93       6.7283993    5.65220  16.0%  33.0   26s
# H32843 10060                       6.7283993    5.65220  16.0%  34.4   29s
#  33759 10207 infeasible   76         6.72840    5.65220  16.0%  34.5   30s
#  40784 10737    6.43574   76   52    6.72840    5.78563  14.0%  36.2   35s
# H46985  8060                       6.5956912    5.81896  11.8%  35.9   38s
#  49124  7537     cutoff   75         6.59569    5.83470  11.5%  36.1   40s
#  52014  6649 infeasible   69         6.59569    5.91221  10.4%  37.8   45s
# H52087  6169                       6.5956912    5.91221  10.4%  37.8   45s
#  58754  6804    6.13457   80   32    6.59569    6.05733  8.16%  38.3   50s
#  73062 11151    6.26994   84   28    6.59569    6.05952  8.13%  34.0   55s
#  83533 14119     cutoff   72         6.59569    6.06777  8.00%  33.9   60s
#  89804 15963    6.19260   78   39    6.59569    6.07188  7.94%  34.7   65s
#  102364 17042    6.11138   62   93    6.59569    6.10209  7.48%  32.9   70s
#  109698 17780     cutoff   82         6.59569    6.11138  7.34%  33.2   75s
#  117991 18030 infeasible   75         6.59569    6.14937  6.77%  33.1   80s
#  124780 19050    6.15816   65  102    6.59569    6.15816  6.63%  33.3   85s
#  129687 19911 infeasible   75         6.59569    6.16363  6.55%  34.2   90s
#  134979 20958    6.16588   72   71    6.59569    6.16588  6.52%  35.0   95s
#  140542 21891    6.43574   82   56    6.59569    6.16588  6.52%  35.8  100s
#  146266 22590 infeasible   75         6.59569    6.16993  6.46%  36.2  111s
# H146555 22590                       6.5956912    6.16993  6.46%  36.2  111s
#  149899 23094    6.16993   71  101    6.59569    6.16993  6.46%  36.6  115s
#  154635 23637     cutoff   82         6.59569    6.17982  6.31%  37.3  120s
#  157654 24366     cutoff   73         6.59569    6.17982  6.31%  38.1  125s
# H159631 24611                       6.5956912    6.17982  6.31%  38.6  128s
#  160549 24801    6.43574   68   66    6.59569    6.17982  6.31%  38.8  130s
#  164890 25636 infeasible   79         6.59569    6.18621  6.21%  39.6  135s
#  168875 26404    6.29826   73   83    6.59569    6.18621  6.21%  40.5  140s
#  172680 27143    6.36142   72   72    6.59569    6.18621  6.21%  41.3  145s
#  177773 28250     cutoff   75         6.59569    6.18621  6.21%  42.3  151s
#  180674 28756    6.49234   76   66    6.59569    6.18621  6.21%  42.9  155s
#  184101 29347     cutoff   74         6.59569    6.18621  6.21%  43.7  160s
#  188026 29804 infeasible   76         6.59569    6.18621  6.21%  44.5  165s
#  193894 30258    6.36954   75   71    6.59569    6.19669  6.05%  44.7  170s
#  198752 30416    6.41426   80   84    6.59569    6.19788  6.03%  45.0  175s
#  202428 31021 infeasible   72         6.59569    6.20361  5.94%  45.6  180s
#  206239 31779    6.36142   73   70    6.59569    6.20361  5.94%  46.4  185s
#  209610 32290    6.24937   77   80    6.59569    6.20361  5.94%  46.9  190s
#  214371 32622 infeasible   80         6.59569    6.21459  5.78%  47.2  195s
#  218488 33256     cutoff   75         6.59569    6.21459  5.78%  47.8  200s
#  222707 33971    6.21459   69  100    6.59569    6.21459  5.78%  48.5  206s
#  225899 34503     cutoff   80         6.59569    6.21459  5.78%  49.1  210s
#  230717 35095    6.39620   80   79    6.59569    6.21459  5.78%  49.7  215s
#  234244 35656 infeasible   76         6.59569    6.21459  5.78%  50.2  220s
# H237838 36106                       6.5956912    6.21459  5.78%  50.7  236s
#  237870 36128    6.57007   68  107    6.59569    6.21459  5.78%  50.7  240s
# H237948 34365                       6.5956912    6.21459  5.78%  50.7  241s
#  241857 34812    6.21459   99   25    6.59569    6.21459  5.78%  50.7  245s
#  249530 33967     cutoff   83         6.59569    6.21459  5.78%  50.5  250s
# H250943 31879                       6.5956912    6.21459  5.78%  50.4  251s
#  256244 30394    6.54507   89   24    6.59569    6.21459  5.78%  50.3  255s
#  264893 28071    6.36142   73   58    6.59569    6.21459  5.78%  49.9  260s
#  277536 27788    6.28135   94   25    6.59569    6.21459  5.78%  48.7  265s
#  293627 27069    6.27920   91   20    6.59569    6.21459  5.78%  47.0  270s
#  307279 25365    6.46574   87   31    6.59569    6.21459  5.78%  45.6  278s
#  309366 25017    6.47931   96   13    6.59569    6.21459  5.78%  45.5  280s
#  319379 22646     cutoff   97         6.59569    6.21459  5.78%  44.9  285s
#  329025 19546    6.32665   76   64    6.59569    6.21459  5.78%  44.6  290s
#  339203 17714     cutoff  108         6.59569    6.21459  5.78%  44.1  295s
#  346267 18926    6.21459   78   65    6.59569    6.21459  5.78%  44.1  300s
#  351486 19775    6.21459   94   31    6.59569    6.21459  5.78%  44.3  305s
#  365076 20452 infeasible   81         6.59569    6.21459  5.78%  43.7  310s
#  370783 20966     cutoff   81         6.59569    6.21459  5.78%  43.8  315s
#  375411 21704    6.52757   83   62    6.59569    6.21459  5.78%  44.1  320s
#  380354 22443    6.36142   82   63    6.59569    6.21459  5.78%  44.5  325s
#  384926 22554    6.39620   89   46    6.59569    6.22241  5.66%  44.7  330s
#  391171 22616     cutoff   89         6.59569    6.24937  5.25%  44.8  335s
#  396933 22556 infeasible   78         6.59569    6.26068  5.08%  44.8  340s
#  407388 23628    6.58817   94   14    6.59569    6.26160  5.07%  44.1  345s
#  419779 24767     cutoff  100         6.59569    6.26183  5.06%  43.1  350s
#  433183 25493    6.27235   80   15    6.59569    6.27235  4.90%  42.3  355s
#  446185 27207     cutoff   90         6.59569    6.27235  4.90%  41.5  360s
#  459434 28961    6.57076   86   14    6.59569    6.27235  4.90%  40.7  365s
#  473864 30548    6.35304   81   24    6.59569    6.27235  4.90%  40.0  370s
#  487536 31217    6.36030   81   42    6.59569    6.27457  4.87%  39.3  375s
#  489831 31376 infeasible   91         6.59569    6.27474  4.87%  39.4  381s
# H489832 31376                       6.5956912    6.27474  4.87%  39.4  381s
#  493299 31756     cutoff   82         6.59569    6.27474  4.87%  39.4  385s
#  498476 32311    6.27474   82   46    6.59569    6.27474  4.87%  39.6  390s
#  503595 32853     cutoff   86         6.59569    6.27474  4.87%  39.8  395s
#  508864 33583    6.32688   77   62    6.59569    6.27474  4.87%  40.0  400s
#  514679 34260    6.27474   77   52    6.59569    6.27474  4.87%  40.1  405s
#  519616 34714    6.41134   78   63    6.59569    6.27474  4.87%  40.3  410s
#  524437 35204    6.27474   77   71    6.59569    6.27474  4.87%  40.5  415s
#  529020 35705    6.33674   90   56    6.59569    6.27474  4.87%  40.7  420s
#  534136 36239    6.35105   84   58    6.59569    6.27474  4.87%  40.9  425s
#  538538 36622    6.34821   79   42    6.59569    6.27474  4.87%  41.1  430s
#  543261 37215    6.57327   86   31    6.59569    6.27474  4.87%  41.3  435s
#  548159 37735 infeasible   85         6.59569    6.27474  4.87%  41.5  440s
#  552802 38301    6.30555   84   68    6.59569    6.27474  4.87%  41.7  445s
#  557631 38842    6.41731   83   41    6.59569    6.27474  4.87%  41.9  450s
#  562316 39343    6.27859   85   78    6.59569    6.27474  4.87%  42.1  455s
#  567963 39925     cutoff   86         6.59569    6.27474  4.87%  42.2  460s
#  573630 40891    6.47931   94   14    6.59569    6.27474  4.87%  42.2  465s
#  584538 42026    6.27505   93   29    6.59569    6.27505  4.86%  41.7  470s
#  594750 42749    6.27505   96   27    6.59569    6.27505  4.86%  41.3  475s
#  608015 44513    6.29905  102   25    6.59569    6.27505  4.86%  40.8  480s
#  619852 46317    6.58817  107   18    6.59569    6.27505  4.86%  40.4  485s
#  631098 47690    6.27505   95   21    6.59569    6.27505  4.86%  40.0  490s
#  642628 48996    6.28580  103   29    6.59569    6.27505  4.86%  39.6  495s
#  653143 49317    6.49972   78   50    6.59569    6.27971  4.79%  39.3  500s
#  661825 49337    6.28580  106   19    6.59569    6.28414  4.72%  39.1  505s
#  666374 49715 infeasible   84         6.59569    6.28414  4.72%  39.3  510s
#  675613 50285    6.32564   94   24    6.59569    6.28580  4.70%  39.1  515s
#  689645 51337     cutoff   87         6.59569    6.28580  4.70%  38.6  520s
#  697405 51631    6.57007   77   56    6.59569    6.29187  4.61%  38.6  525s
#  699598 51821    6.49006   86   18    6.59569    6.29187  4.61%  38.7  531s
#  705769 51578     cutoff   84         6.59569    6.29815  4.51%  38.6  535s
#  712891 51554    6.39086   77   36    6.59569    6.30555  4.40%  38.5  540s
#  718534 51753     cutoff   90         6.59569    6.30555  4.40%  38.6  545s
#  728940 51107 infeasible   82         6.59569    6.31892  4.20%  38.4  550s
#  735477 51414    6.36873   91   60    6.59569    6.32665  4.08%  38.5  555s
#  740132 51873     cutoff   86         6.59569    6.32665  4.08%  38.7  560s
#  745207 52189 infeasible   81         6.59569    6.32665  4.08%  38.8  565s
#  749904 52487    6.39620   81   75    6.59569    6.32665  4.08%  39.0  570s
#  755069 53031    6.32665   82   73    6.59569    6.32665  4.08%  39.2  575s
#  760152 53492     cutoff   86         6.59569    6.32665  4.08%  39.4  580s
#  765003 53794 infeasible   87         6.59569    6.32665  4.08%  39.6  586s
#  770290 53836    6.56150   86   31    6.59569    6.32688  4.08%  39.6  590s
#  776245 53880    6.36954   88   48    6.59569    6.32688  4.08%  39.7  597s
#  779241 53947     cutoff   89         6.59569    6.32688  4.08%  39.7  600s
#  785780 54070    6.56150   87   31    6.59569    6.32688  4.08%  39.7  605s
#  793232 54295    6.32688   77   63    6.59569    6.32688  4.08%  39.8  610s
#  799232 54012    6.33088   93   42    6.59569    6.33023  4.02%  39.9  615s
#
# Cutting planes:
#   Learned: 9
#   Gomory: 165
#   Cover: 73
#   Implied bound: 5
#   Projected implied bound: 2
#   MIR: 502
#   Flow cover: 1265
#   GUB cover: 6
#   Inf proof: 112
#   Zero half: 19
#   RLT: 40
#   Relax-and-lift: 43
#
# Explored 800422 nodes (31984898 simplex iterations) in 615.94 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.59569 6.59569 6.59569 ... 6.7284
#
# Optimal solution found (tolerance 4.00e-02)
# Best objective 6.595691167431e+00, best bound 6.332320052624e+00, gap 3.9931%
# Changed value of parameter MIPGap to 0.04
#    Prev: 0.0001  Min: 0.0  Max: inf  Default: 0.0001
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 732 rows, 374 columns and 3182 nonzeros
# Model fingerprint: 0xe03b5e5d
# Variable types: 50 continuous, 324 integer (324 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [7e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 7.9475706
# Presolve removed 48 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 684 rows, 337 columns, 3166 nonzeros
# Variable types: 46 continuous, 291 integer (291 binary)
#
# Root relaxation: objective 2.160798e+00, 188 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.16080    0  157    7.94757    2.16080  72.8%     -    0s
# H    0     0                       7.9036334    2.16080  72.7%     -    0s
# H    0     0                       7.2922630    2.16080  70.4%     -    0s
#      0     0    4.71083    0  180    7.29226    4.71083  35.4%     -    0s
#      0     0    4.71083    0  136    7.29226    4.71083  35.4%     -    0s
#      0     2    4.71083    0  131    7.29226    4.71083  35.4%     -    0s
# H  333   285                       7.2665637    4.71083  35.2%  16.9    0s
# H 3220  1377                       7.2225817    5.07510  29.7%  11.3    2s
# H 3226  1312                       7.2016683    5.13962  28.6%  11.3    2s
# H 3248  1261                       7.1955528    5.39620  25.0%  14.5    3s
# H 3384  1275                       7.1041680    5.48244  22.8%  16.4    4s
# H 3403  1210                       6.9903687    5.48244  21.6%  16.4    4s
# H 3427  1159                       6.9646694    5.48244  21.3%  16.5    4s
#   3694  1197    6.54749   46   56    6.96467    5.58563  19.8%  17.3    5s
#  12232  3555    6.38997   59   92    6.96467    5.76733  17.2%  32.4   10s
# H15151  4485                       6.9283659    5.76965  16.7%  32.8   14s
#  15165  4516    6.26714   64   69    6.92837    5.76965  16.7%  32.7   15s
# H15210  4294                       6.8988927    5.76965  16.4%  32.7   15s
# H15219  4083                       6.7953354    5.76965  15.1%  32.7   15s
#  21641  4275    6.09940   68   76    6.79534    5.84710  14.0%  34.9   20s
#  29168  4544    5.94717   74   44    6.79534    5.94101  12.6%  36.5   25s
#  37723  6941    6.01740   73   48    6.79534    5.95395  12.4%  36.2   30s
#  44710  8030    6.05917   79  136    6.79534    6.00970  11.6%  37.0   45s
#  44749  8056    6.70372   73  129    6.79534    6.00970  11.6%  36.9   50s
# H44771  7666                       6.7774676    6.00970  11.3%  36.9   54s
#  44777  7670    6.64094   67  140    6.77747    6.00970  11.3%  36.9   55s
#  44802  7686    6.51952   62  104    6.77747    6.00970  11.3%  36.9   60s
#  45429  7829    6.74105   83   50    6.77747    6.00970  11.3%  38.3   65s
#  51462  7471 infeasible   80         6.77747    6.00970  11.3%  40.0   70s
#  52580  7304 infeasible   80         6.77747    6.01638  11.2%  40.3   75s
#  56841  6459    6.34846   83   69    6.77747    6.05587  10.6%  43.0   80s
# H57650  5855                       6.7774676    6.05789  10.6%  44.0   81s
#  60669  5109    6.26544   80   73    6.77747    6.08664  10.2%  46.0   85s
#  68021  4778    6.41711   98   68    6.77747    6.14571  9.32%  45.5   90s
#  77798  7967     cutoff   96         6.77747    6.15430  9.19%  43.5   95s
#  89229 11515     cutoff  101         6.77747    6.15430  9.19%  40.5  100s
#  90109 11516    6.35181   84  136    6.77747    6.15430  9.19%  40.3  107s
#  90130 11530    6.19490   80   96    6.77747    6.15430  9.19%  40.3  110s
#  90164 11553    6.39715   86   97    6.77747    6.15430  9.19%  40.3  115s
#  90196 11574    6.39715   81  124    6.77747    6.15430  9.19%  40.3  120s
#  90227 11595    6.17706   94  102    6.77747    6.15430  9.19%  40.3  125s
#  90258 11615    6.27839   86  136    6.77747    6.15430  9.19%  40.3  130s
#  90287 11635    6.33337   92  103    6.77747    6.15430  9.19%  40.3  135s
#  90317 11657    6.43772   74   57    6.77747    6.15430  9.19%  41.5  140s
# *90699 11180             101       6.7243238    6.15430  8.48%  41.6  141s
# *91176 10656             116       6.6697052    6.15430  7.73%  41.7  142s
#  92786 10740    6.15430   91   34    6.66971    6.15430  7.73%  42.3  145s
#  97063 10580     cutoff   99         6.66971    6.15430  7.73%  43.7  150s
#  103460 10391    6.15430   88   97    6.66971    6.15430  7.73%  44.1  155s
#  106018  9937     cutoff  107         6.66971    6.15430  7.73%  43.9  160s
#  111718  9265    6.40130   98   73    6.66971    6.15430  7.73%  44.0  165s
#  116627  8034    6.31341   96   82    6.66971    6.15430  7.73%  44.9  170s
#  119566  7236    6.15430  111  136    6.66971    6.15430  7.73%  45.5  185s
#  119599  7258    6.56354  100  115    6.66971    6.15430  7.73%  45.5  190s
#  119632  7280    6.15430   92   86    6.66971    6.15430  7.73%  45.5  195s
#  119662  7300    6.20027   98   87    6.66971    6.15430  7.73%  45.4  200s
#  119728  7347    6.15430   92   60    6.66971    6.15430  7.73%  46.0  205s
#  121369  7271    6.33337  103   76    6.66971    6.15430  7.73%  46.5  210s
#  126579  6680 infeasible  107         6.66971    6.15430  7.73%  47.4  215s
#  130366  5823    6.66617  102   64    6.66971    6.15430  7.73%  49.1  220s
#  133258  5518 infeasible  105         6.66971    6.15430  7.73%  49.9  225s
#  141223  5592 infeasible  111         6.66971    6.15430  7.73%  49.1  230s
#  148801  6544    6.42015  106   27    6.66971    6.17435  7.43%  48.6  235s
#  157081  6564     cutoff  113         6.66971    6.22047  6.74%  48.0  240s
#  162358  6514    6.34846  103  100    6.66971    6.26544  6.06%  47.9  245s
#  165476  6750 infeasible  106         6.66971    6.26923  6.00%  48.9  250s
#  169184  6582    6.60129   98   62    6.66971    6.30271  5.50%  49.6  255s
#  171676  6449    6.39316  106   92    6.66971    6.31620  5.30%  50.4  260s
#  174009  6520 infeasible  108         6.66971    6.32959  5.10%  51.7  265s
#  180265  8691    6.33337   98   95    6.66971    6.33000  5.09%  51.2  271s
#  188719 11465     cutoff  118         6.66971    6.33000  5.09%  49.9  276s
# H192912 12269                       6.6697052    6.33000  5.09%  49.2  294s
#  192913 12270    6.65036  106  136    6.66971    6.33000  5.09%  49.2  295s
#  192949 12294    6.48653  110  105    6.66971    6.33000  5.09%  49.2  300s
#  192978 12313    6.34807  102   85    6.66971    6.33000  5.09%  49.2  305s
#  193190 12419     cutoff  125         6.66971    6.33000  5.09%  49.5  310s
#  196502 12385    6.51952  114   44    6.66971    6.33000  5.09%  50.1  315s
#  198861 12111    6.33000  113  104    6.66971    6.33000  5.09%  50.7  323s
#  200267 12117    6.43148  116   64    6.66971    6.33000  5.09%  51.0  325s
#  205587 11166    6.60129  117   67    6.66971    6.33000  5.09%  51.4  330s
#  207442 10934    6.63903  117   69    6.66971    6.33000  5.09%  52.4  335s
#  209844 10369 infeasible  124         6.66971    6.33000  5.09%  53.4  340s
#  212653  9709     cutoff  120         6.66971    6.33000  5.09%  54.3  345s
#  214805  9166 infeasible  113         6.66971    6.33000  5.09%  55.4  350s
#  216665  8582 infeasible  117         6.66971    6.33000  5.09%  56.4  355s
#  217983  8179    6.34846  122   58    6.66971    6.33000  5.09%  57.3  360s
#  220299  7387    6.33000  117   74    6.66971    6.33000  5.09%  58.4  365s
#  222780  6540     cutoff  121         6.66971    6.33000  5.09%  59.2  370s
#  223738  6222    6.47299  123  136    6.66971    6.33000  5.09%  59.5  381s
#  223766  6241    6.64094  109  114    6.66971    6.33000  5.09%  59.5  385s
#  223796  6261    6.34846  115  112    6.66971    6.33000  5.09%  59.5  390s
#  223829  6283    6.60129  122   95    6.66971    6.33000  5.09%  59.5  395s
#  223861  6304    6.34846  115   94    6.66971    6.33000  5.09%  59.5  400s
#  223893  6325    6.62137  119   90    6.66971    6.33000  5.09%  59.5  405s
#  223927  6348    6.34846  121   90    6.66971    6.33000  5.09%  59.5  410s
#  224577  6462    6.33000  121   99    6.66971    6.33000  5.09%  60.0  415s
#  228639  6391    6.33000  127   45    6.66971    6.33000  5.09%  60.2  420s
#  236921  6312    6.33000  138   23    6.66971    6.33000  5.09%  59.4  425s
#  245034  6224    6.33000  134   46    6.66971    6.33000  5.09%  58.8  430s
#  251912  6885    6.34846  127   74    6.66971    6.33000  5.09%  58.7  435s
#  256409  7089 infeasible  145         6.66971    6.33000  5.09%  58.9  444s
#  256476  7103 infeasible  141         6.66971    6.33000  5.09%  58.9  445s
#  263988  7723    6.39715  150   22    6.66971    6.33000  5.09%  58.4  450s
#  269634  8418    6.65036  147   44    6.66971    6.33000  5.09%  58.4  455s
#  275060  9937    6.64280  144   39    6.66971    6.33000  5.09%  58.6  460s
#  280082 11408    6.38243  141   61    6.66971    6.33000  5.09%  58.8  465s
#  284815 12814    6.33000  135   80    6.66971    6.33000  5.09%  58.9  470s
#  292129 14568    6.33000  140   31    6.66971    6.33000  5.09%  58.5  475s
#  302717 16757    6.33000  137   18    6.66971    6.33000  5.09%  57.3  480s
#  312108 18192 infeasible  137         6.66971    6.33000  5.09%  56.5  485s
#  319339 19368 infeasible  137         6.66971    6.33000  5.09%  56.1  490s
#  325874 20400     cutoff  150         6.66971    6.33000  5.09%  56.0  495s
#  331836 21289 infeasible  138         6.66971    6.33000  5.09%  55.8  500s
#  339985 22481    6.33000  136   35    6.66971    6.33000  5.09%  55.3  505s
#  348259 23686 infeasible  142         6.66971    6.33000  5.09%  54.8  510s
#  356907 24355 infeasible  144         6.66971    6.33000  5.09%  54.3  515s
#  362290 25380    6.38243  145   52    6.66971    6.33000  5.09%  54.3  520s
#  368503 25702    6.33000  146   44    6.66971    6.33000  5.09%  54.1  525s
#  375309 25982     cutoff  146         6.66971    6.33000  5.09%  53.8  530s
#  382641 26448    6.33000  148   32    6.66971    6.33000  5.09%  53.4  535s
#  391313 26687    6.61850  150   11    6.66971    6.33000  5.09%  52.8  540s
#  400693 26843    6.33000  147   22    6.66971    6.33000  5.09%  52.1  545s
#  409026 26489 infeasible  145         6.66971    6.33000  5.09%  51.6  550s
#  414732 25802 infeasible  144         6.66971    6.33000  5.09%  51.5  555s
#  418401 25591    6.33000  136   34    6.66971    6.33000  5.09%  51.3  560s
#  425605 24680    6.33000  136   30    6.66971    6.33000  5.09%  51.0  565s
#  431880 24605    6.33000  138   37    6.66971    6.33000  5.09%  50.7  570s
#  436982 24448    6.63903  137   47    6.66971    6.33000  5.09%  50.7  575s
#  443984 23686    6.46322  136   61    6.66971    6.33000  5.09%  50.5  580s
#  447118 24064 infeasible  138         6.66971    6.33000  5.09%  50.7  585s
#  455395 24590     cutoff  153         6.66971    6.33337  5.04%  50.3  590s
#  459602 25245    6.33337  152   55    6.66971    6.33337  5.04%  50.5  595s
#  464301 25894    6.39481  143   54    6.66971    6.33337  5.04%  50.7  600s
#  468245 26406    6.61372  145   37    6.66971    6.33337  5.04%  50.9  605s
#  473487 27078    6.33337  150   55    6.66971    6.33337  5.04%  51.0  610s
#  474475 27078    6.38243  157   45    6.66971    6.33337  5.04%  51.1  619s
#  474488 27220    6.51002  157   34    6.66971    6.33337  5.04%  51.1  620s
#  479158 27891    6.39375  146   59    6.66971    6.33337  5.04%  51.2  625s
#  484223 28506 infeasible  153         6.66971    6.33337  5.04%  51.3  630s
#  488589 28989 infeasible  151         6.66971    6.33337  5.04%  51.5  635s
#  494712 29709    6.60129  152   38    6.66971    6.33337  5.04%  51.6  640s
#  499124 30353    6.38243  151   65    6.66971    6.33337  5.04%  51.8  645s
#  504020 30988 infeasible  142         6.66971    6.33337  5.04%  51.9  650s
#  508734 31495 infeasible  151         6.66971    6.33337  5.04%  52.0  655s
#  513467 32122     cutoff  146         6.66971    6.33337  5.04%  52.2  660s
#  518304 32640    6.33337  141   62    6.66971    6.33337  5.04%  52.3  666s
#  522987 33297    6.66617  143   43    6.66971    6.33337  5.04%  52.5  671s
#  528041 33926     cutoff  151         6.66971    6.33337  5.04%  52.6  676s
#  532721 34472    6.43526  150   46    6.66971    6.33337  5.04%  52.7  681s
#  536475 34999    6.38243  136   58    6.66971    6.33337  5.04%  52.8  685s
#  541424 35640    6.39671  148   52    6.66971    6.33337  5.04%  52.9  690s
#  545692 36285     cutoff  143         6.66971    6.33337  5.04%  53.0  695s
#  550557 37010     cutoff  154         6.66971    6.33337  5.04%  53.1  700s
#  555065 37444    6.44281  133   56    6.66971    6.33337  5.04%  53.2  705s
#  558464 37859     cutoff  153         6.66971    6.33337  5.04%  53.3  710s
#  563495 38743 infeasible  145         6.66971    6.33337  5.04%  53.4  715s
#  567173 39190    6.58119  149   33    6.66971    6.33337  5.04%  53.5  720s
#  571996 39845    6.33337  138   86    6.66971    6.33337  5.04%  53.6  725s
#  576656 40441     cutoff  132         6.66971    6.33337  5.04%  53.7  730s
#  581275 41090    6.37560  148   46    6.66971    6.33337  5.04%  53.8  736s
#  584537 41469    6.33337  136   69    6.66971    6.33337  5.04%  54.0  740s
#  589361 42135 infeasible  140         6.66971    6.33337  5.04%  54.1  746s
#  593258 42710 infeasible  150         6.66971    6.33337  5.04%  54.2  750s
#  598357 43374    6.48121  147   50    6.66971    6.33337  5.04%  54.3  755s
#  602851 43992     cutoff  156         6.66971    6.33337  5.04%  54.4  760s
#  608043 44537 infeasible  144         6.66971    6.33337  5.04%  54.5  765s
#  611839 45081     cutoff  155         6.66971    6.33337  5.04%  54.6  770s
#  616347 45650    6.58802  144   45    6.66971    6.33337  5.04%  54.7  775s
#  620558 45958    6.66617  127   54    6.66971    6.33337  5.04%  54.8  780s
#  622853 46319 infeasible  139         6.66971    6.33337  5.04%  55.0  785s
#  625512 46762     cutoff  126         6.66971    6.33337  5.04%  55.3  790s
#  627496 47134 infeasible  138         6.66971    6.33337  5.04%  55.6  795s
#  629789 47416    6.37350  135   83    6.66971    6.33337  5.04%  55.9  801s
#  631289 47604 infeasible  138         6.66971    6.33337  5.04%  56.1  805s
#  633634 47922    6.60129  128   72    6.66971    6.33337  5.04%  56.5  811s
#  635627 48121     cutoff  150         6.66971    6.33337  5.04%  56.8  823s
#  636303 48218 infeasible  138         6.66971    6.33337  5.04%  56.9  826s
#  638324 48494    6.33337  135   86    6.66971    6.33337  5.04%  57.3  831s
#  639748 48605    6.37336  137   86    6.66971    6.33337  5.04%  57.5  835s
#  642042 48948    6.35224  132   84    6.66971    6.33337  5.04%  57.9  840s
#  645849 48935     cutoff  142         6.66971    6.33337  5.04%  58.1  846s
#  650571 48797    6.52124  151   16    6.66971    6.34241  4.91%  58.1  851s
#  654905 48925 infeasible  135         6.66971    6.34585  4.86%  58.2  856s
#  658075 48762 infeasible  134         6.66971    6.34846  4.82%  58.2  860s
#  660741 48730    6.34846  130   87    6.66971    6.34846  4.82%  58.5  865s
#  664642 48937     cutoff  150         6.66971    6.34937  4.80%  58.6  870s
#  668748 49081    6.38243  151   63    6.66971    6.34937  4.80%  58.6  875s
#  673758 48946    6.60129  141   46    6.66971    6.35224  4.76%  58.7  881s
#  677711 49095    6.65829  144   30    6.66971    6.35224  4.76%  58.7  885s
#  682347 49687    6.40130  143   62    6.66971    6.35224  4.76%  58.8  891s
#  685699 50016    6.58119  137   57    6.66971    6.35224  4.76%  58.9  896s
#  689068 50391    6.62466  135   34    6.66971    6.35224  4.76%  59.0  901s
#  692271 50717 infeasible  132         6.66971    6.35224  4.76%  59.1  905s
#  695393 51072     cutoff  146         6.66971    6.35224  4.76%  59.3  910s
#  699186 51498    6.35224  146   47    6.66971    6.35224  4.76%  59.3  915s
#  702153 51930     cutoff  144         6.66971    6.35224  4.76%  59.5  920s
#  705915 52359 infeasible  138         6.66971    6.35224  4.76%  59.6  925s
#  709799 52736    6.35224  141   67    6.66971    6.35224  4.76%  59.7  930s
#  712956 53090 infeasible  145         6.66971    6.35224  4.76%  59.8  935s
#  716275 53305 infeasible  138         6.66971    6.35224  4.76%  59.9  940s
#  719192 53679     cutoff  138         6.66971    6.35224  4.76%  60.0  945s
#  723396 54441    6.62466  140   47    6.66971    6.35224  4.76%  60.0  950s
#  727080 54987    6.40130  142   52    6.66971    6.35224  4.76%  60.1  955s
#  731711 55543 infeasible  135         6.66971    6.35224  4.76%  60.2  960s
#  735241 55984    6.58119  144   39    6.66971    6.35224  4.76%  60.3  966s
#  737615 56413     cutoff  147         6.66971    6.35224  4.76%  60.4  971s
#  740348 56639 infeasible  141         6.66971    6.35224  4.76%  60.6  975s
#  742890 56799    6.35457  149   72    6.66971    6.35224  4.76%  60.7  980s
#  746075 57104    6.35591  131   73    6.66971    6.35224  4.76%  61.0  986s
#  748536 57257    6.35224  137   68    6.66971    6.35224  4.76%  61.1  991s
#  751141 57472    6.35224  130   60    6.66971    6.35224  4.76%  61.3  995s
#  753288 57659    6.37711  144   66    6.66971    6.35224  4.76%  61.5 1000s
#  754683 57735     cutoff  136         6.66971    6.35224  4.76%  61.7 1006s
#  755365 57847 infeasible  133         6.66971    6.35224  4.76%  61.7 1010s
#  757762 58105 infeasible  138         6.66971    6.35224  4.76%  62.0 1015s
#  760444 58439    6.41711  136   63    6.66971    6.35224  4.76%  62.2 1020s
#  764486 58417    6.40130  144   43    6.66971    6.35224  4.76%  62.2 1025s
#  768433 58426    6.57656  156   41    6.66971    6.35673  4.69%  62.3 1030s
#  773926 58572    6.66617  149   44    6.66971    6.35673  4.69%  62.2 1036s
#  778468 58747     cutoff  149         6.66971    6.35673  4.69%  62.2 1041s
#  782932 58888 infeasible  150         6.66971    6.35673  4.69%  62.2 1046s
#  787004 58980    6.35673  147   55    6.66971    6.35673  4.69%  62.2 1050s
#  793166 59143     cutoff  154         6.66971    6.35673  4.69%  62.2 1056s
#  796719 59310    6.40130  147   51    6.66971    6.35673  4.69%  62.2 1060s
#  801631 59534 infeasible  149         6.66971    6.35673  4.69%  62.2 1065s
#  806302 59747 infeasible  155         6.66971    6.35673  4.69%  62.3 1070s
#  809565 59880    6.48432  143   45    6.66971    6.35673  4.69%  62.3 1075s
#  814351 60084     cutoff  150         6.66971    6.35673  4.69%  62.3 1080s
#  818287 60187 infeasible  141         6.66971    6.35673  4.69%  62.3 1085s
#  822766 60430    6.63960  144   32    6.66971    6.35673  4.69%  62.4 1090s
#  826536 60620 infeasible  150         6.66971    6.35673  4.69%  62.4 1095s
#  830946 60729     cutoff  144         6.66971    6.35673  4.69%  62.4 1101s
#  833623 60683    6.56482  143   42    6.66971    6.35673  4.69%  62.5 1105s
#  839276 60338    6.51991  145   53    6.66971    6.35721  4.69%  62.3 1110s
#  844662 60456    6.42700  141   71    6.66971    6.35889  4.66%  62.2 1115s
#  850712 60559    6.57625  142   41    6.66971    6.36015  4.64%  62.1 1120s
#  852658 60558    6.56232  140   74    6.66971    6.36046  4.64%  62.1 1128s
#  854714 60556    6.46700  136   83    6.66971    6.36133  4.62%  62.1 1130s
#  860084 60510 infeasible  150         6.66971    6.36351  4.59%  62.0 1135s
#  862998 60300    6.38243  129   67    6.66971    6.36592  4.55%  62.1 1140s
#  867444 60207     cutoff  147         6.66971    6.36824  4.52%  62.1 1146s
#  871688 60277 infeasible  147         6.66971    6.36841  4.52%  62.0 1150s
#  876882 60196    6.46036  150   42    6.66971    6.36918  4.51%  62.0 1155s
#  882589 60056     cutoff  136         6.66971    6.36937  4.50%  61.9 1160s
#  885596 59982    6.59909  141   79    6.66971    6.37013  4.49%  62.0 1165s
#  891223 60248    6.39667  144   44    6.66971    6.37311  4.45%  62.0 1171s
#  896575 61022    6.39667  136   57    6.66971    6.37330  4.44%  62.0 1176s
#  901445 61816    6.41711  155   43    6.66971    6.37330  4.44%  62.0 1180s
#  906205 62029 infeasible  135         6.66971    6.37398  4.43%  61.9 1185s
#  910558 61787 infeasible  152         6.66971    6.37560  4.41%  61.9 1190s
#  915836 61586    6.44281  147   40    6.66971    6.37560  4.41%  61.9 1195s
#  920601 61466     cutoff  146         6.66971    6.37560  4.41%  61.9 1200s
#  925134 61440    6.37560  144   57    6.66971    6.37560  4.41%  61.9 1205s
#  930659 61618     cutoff  144         6.66971    6.37560  4.41%  61.8 1210s
#  935291 61755 infeasible  149         6.66971    6.37560  4.41%  61.8 1215s
#  939801 61953 infeasible  145         6.66971    6.37560  4.41%  61.8 1220s
#  943907 62102    6.62466  142   46    6.66971    6.37560  4.41%  61.8 1225s
#  947628 62116    6.43598  137   71    6.66971    6.37560  4.41%  61.9 1230s
#  950656 61949    6.38494  148   64    6.66971    6.37560  4.41%  61.9 1235s
#  954444 61627 infeasible  135         6.66971    6.37760  4.38%  61.9 1240s
#  960062 61238    6.50986  146   51    6.66971    6.38076  4.33%  61.9 1245s
#  964407 61122     cutoff  152         6.66971    6.38243  4.31%  61.9 1250s
#  969638 61017 infeasible  144         6.66971    6.38243  4.31%  61.9 1255s
#  974488 60891 infeasible  139         6.66971    6.38243  4.31%  61.8 1260s
#  979181 60768     cutoff  145         6.66971    6.38243  4.31%  61.8 1265s
#  983856 60755    6.38243  140   56    6.66971    6.38243  4.31%  61.9 1270s
#  988454 60745     cutoff  150         6.66971    6.38243  4.31%  61.9 1276s
#  993241 60557 infeasible  154         6.66971    6.38243  4.31%  61.9 1281s
#  996798 60500     cutoff  142         6.66971    6.38243  4.31%  61.9 1285s
#  1001342 60443    6.56377  149   59    6.66971    6.38243  4.31%  61.9 1290s
#  1006217 60481     cutoff  147         6.66971    6.38243  4.31%  61.9 1307s
#  1008552 60437 infeasible  150         6.66971    6.38243  4.31%  61.9 1311s
#  1012049 60448     cutoff  151         6.66971    6.38243  4.31%  61.9 1315s
#  1016726 60377    6.38243  142   52    6.66971    6.38243  4.31%  61.9 1321s
#  1020427 60360    6.38243  144   60    6.66971    6.38243  4.31%  61.9 1325s
#  1024844 60360 infeasible  153         6.66971    6.38243  4.31%  62.0 1330s
#  1027784 60397    6.38243  142   75    6.66971    6.38243  4.31%  62.1 1335s
#  1030271 60467    6.38243  142   91    6.66971    6.38243  4.31%  62.3 1341s
#  1032179 60532    6.53309  140   44    6.66971    6.38243  4.31%  62.4 1346s
#  1033747 60608    6.54658  143   60    6.66971    6.38243  4.31%  62.5 1351s
# H1033828 60608                       6.6697052    6.38243  4.31%  62.5 1351s
#  1035068 60728 infeasible  142         6.66971    6.38243  4.31%  62.6 1355s
#  1037768 60848    6.38312  139   82    6.66971    6.38243  4.31%  62.8 1361s
#  1039387 60918     cutoff  140         6.66971    6.38243  4.31%  63.0 1365s
#  1042318 61107    6.48258  143   59    6.66971    6.38243  4.31%  63.2 1372s
#  1044639 61196    6.45343  140   64    6.66971    6.38243  4.31%  63.3 1376s
#  1046475 61233    6.42205  135   71    6.66971    6.38243  4.31%  63.5 1381s
#  1048401 61272    6.65036  139   53    6.66971    6.38243  4.31%  63.6 1386s
#  1050368 61286    6.44177  141   72    6.66971    6.38243  4.31%  63.8 1392s
#  1051469 61319    6.62796  148   45    6.66971    6.38243  4.31%  63.9 1395s
#  1053743 61411    6.56340  146   65    6.66971    6.38243  4.31%  64.1 1401s
#  1056157 61578    6.39956  138   83    6.66971    6.38243  4.31%  64.3 1407s
#  1058717 61693     cutoff  146         6.66971    6.38243  4.31%  64.4 1412s
#  1059694 61736    6.40702  152   72    6.66971    6.38243  4.31%  64.5 1415s
#  1061884 61797    6.39450  140   82    6.66971    6.38243  4.31%  64.6 1420s
#  1063742 61914    6.58802  137   57    6.66971    6.38243  4.31%  64.8 1425s
#  1065865 61955    6.60689  146   46    6.66971    6.38243  4.31%  65.0 1430s
#  1068237 61940    6.55757  141   55    6.66971    6.38243  4.31%  65.1 1435s
#  1070654 61805     cutoff  150         6.66971    6.38243  4.31%  65.2 1440s
#  1076273 61385     cutoff  147         6.66971    6.38492  4.27%  65.2 1446s
#  1079632 61087    6.39635  146   55    6.66971    6.38664  4.24%  65.1 1450s
#  1083925 60806    6.38886  132   82    6.66971    6.38814  4.22%  65.2 1456s
#  1087567 60697    6.57656  140   41    6.66971    6.38899  4.21%  65.2 1460s
#  1090825 60312    6.52583  145   44    6.66971    6.39007  4.19%  65.3 1466s
#  1093852 59961     cutoff  142         6.66971    6.39157  4.17%  65.3 1471s
#  1097215 59773    6.50706  150   36    6.66971    6.39346  4.14%  65.3 1475s
#  1102144 60147    6.64280  138   43    6.66971    6.39375  4.14%  65.2 1480s
#  1107720 60504    6.41862  144   61    6.66971    6.39375  4.14%  65.2 1486s
#  1111913 60767    6.44281  149   43    6.66971    6.39375  4.14%  65.1 1490s
#  1116868 61267    6.39375  133   43    6.66971    6.39375  4.14%  65.1 1495s
#  1121872 61725     cutoff  146         6.66971    6.39375  4.14%  65.1 1501s
#  1127236 62113     cutoff  152         6.66971    6.39375  4.14%  65.0 1505s
#  1131885 62446    6.40543  154   55    6.66971    6.39375  4.14%  65.0 1510s
#  1136525 62817 infeasible  152         6.66971    6.39375  4.14%  65.0 1515s
#  1139817 63091 infeasible  155         6.66971    6.39375  4.14%  64.9 1520s
#  1143273 63309    6.66617  136   58    6.66971    6.39375  4.14%  64.9 1525s
#  1147725 63729     cutoff  148         6.66971    6.39375  4.14%  64.9 1530s
#  1152661 64114 infeasible  143         6.66971    6.39375  4.14%  64.9 1535s
#  1157093 64384    6.41711  152   52    6.66971    6.39375  4.14%  64.9 1541s
#  1160741 64690    6.55153  149   29    6.66971    6.39375  4.14%  64.9 1545s
#  1165656 65108    6.59700  138   48    6.66971    6.39375  4.14%  64.9 1550s
#  1170342 65556    6.39375  147   55    6.66971    6.39375  4.14%  64.9 1555s
#  1176066 65888    6.39375  136   70    6.66971    6.39375  4.14%  64.8 1561s
#  1179024 65841    6.47688  143   52    6.66971    6.39375  4.14%  64.9 1566s
#  1183873 65728    6.39491  144   59    6.66971    6.39411  4.13%  64.8 1570s
#  1188956 65518     cutoff  153         6.66971    6.39411  4.13%  64.7 1575s
#  1194035 65180    6.46482  144   52    6.66971    6.39491  4.12%  64.7 1581s
#  1197583 65003    6.39667  139   50    6.66971    6.39577  4.11%  64.7 1593s
# H1197584 65003                       6.6697050    6.39577  4.11%  64.7 1593s
#  1198305 64861     cutoff  161         6.66971    6.39632  4.10%  64.7 1595s
#  1203572 65283     cutoff  147         6.66971    6.39667  4.09%  64.6 1600s
#  1210625 65031    6.45781  152   21    6.66971    6.39715  4.09%  64.4 1606s
#  1217950 64743    6.47292  142   18    6.66971    6.39715  4.09%  64.2 1610s
#  1225453 64310 infeasible  132         6.66971    6.39827  4.07%  64.0 1615s
#  1230784 63883    6.50526  139   53    6.66971    6.40045  4.04%  63.9 1620s
#  1236648 63249     cutoff  148         6.66971    6.40130  4.02%  63.9 1626s
#  1241215 62935 infeasible  146         6.66971    6.40130  4.02%  63.8 1630s
#  1246645 62533    6.40130  145   58    6.66971    6.40130  4.02%  63.7 1635s
#  1253078 62377    6.49805  138   46    6.66971    6.40130  4.02%  63.7 1640s
#  1257076 62284 infeasible  149         6.66971    6.40130  4.02%  63.7 1645s
#  1261765 62295     cutoff  141         6.66971    6.40130  4.02%  63.7 1651s
#  1264699 62391    6.40569  145   68    6.66971    6.40130  4.02%  63.7 1655s
#  1267191 62347     cutoff  139         6.66971    6.40130  4.02%  63.8 1660s
#
# Cutting planes:
#   Learned: 12
#   Gomory: 166
#   Cover: 36
#   Implied bound: 16
#   MIR: 634
#   Flow cover: 1697
#   Inf proof: 281
#   Zero half: 2
#   Network: 1
#   RLT: 36
#   Relax-and-lift: 85
#
# Explored 1269947 nodes (81022153 simplex iterations) in 1663.32 seconds
# Thread count was 8 (of 8 available processors)
#
# Solution count 10: 6.66971 6.66971 6.66971 ... 6.92837
#
# Optimal solution found (tolerance 4.00e-02)
# Best objective 6.669705158625e+00, best bound 6.403000935759e+00, gap 3.9987%
# Changed value of parameter MIPGap to 0.04
#    Prev: 0.0001  Min: 0.0  Max: inf  Default: 0.0001
# Gurobi Optimizer version 9.0.3 build v9.0.3rc0 (win64)
# Optimize a model with 760 rows, 382 columns and 3246 nonzeros
# Model fingerprint: 0xac59cb3f
# Variable types: 54 continuous, 328 integer (328 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 2e+02]
#   Objective range  [5e-04, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [2e+00, 3e+02]
# Found heuristic solution: objective 7.9113435
# Presolve removed 52 rows and 37 columns
# Presolve time: 0.01s
# Presolved: 708 rows, 345 columns, 3238 nonzeros
# Variable types: 50 continuous, 295 integer (295 binary)
#
# Root relaxation: objective 2.100159e+00, 187 iterations, 0.00 seconds
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0    2.10016    0  161    7.91134    2.10016  73.5%     -    0s
# H    0     0                       7.2936558    2.10016  71.2%     -    0s
# H    0     0                       7.2287801    2.10016  70.9%     -    0s
#      0     0    5.21149    0  207    7.22878    5.21149  27.9%     -    0s
#      0     0    5.21149    0  147    7.22878    5.21149  27.9%     -    0s
#      0     2    5.21149    0  135    7.22878    5.21149  27.9%     -    0s
# H 3145  1523                       7.1657528    5.21149  27.3%  15.7    2s
# H 3461  1605                       7.1576388    5.62367  21.4%  18.2    3s
# H 3462  1532                       7.1248596    5.62367  21.1%  18.2    3s
# H 4983  1819                       7.1076679    5.67902  20.1%  21.6    4s
#   5680  1972     cutoff   86         7.10767    5.67902  20.1%  23.0    5s
# H 7561  2343                       7.0790439    5.67902  19.8%  25.1    6s
#  18245  7510    6.27715   66   61    7.07904    5.70075  19.5%  30.2   10s
# *18600  7422              85       7.0490966    5.70287  19.1%  30.3   10s
#  29074 12742    6.17579   60  147    7.04910    5.70999  19.0%  30.2   17s
#  29095 12756    6.46343   67  106    7.04910    5.70999  19.0%  30.2   20s
#  29130 12779    6.94818   64   61    7.04910    5.70999  19.0%  30.2   25s
#  29169 12805    6.64267   72   83    7.04910    5.70999  19.0%  30.1   30s
#  31469 13404    5.75873   66  113    7.04910    5.71484  18.9%  32.2   36s
# *33310 13015              94       7.0430060    5.74001  18.5%  33.4   37s
# *37508 12953              97       6.9950671    5.80352  17.0%  36.2   39s
#  37556 13031    6.87995   77   47    6.99507    5.81072  16.9%  36.3   40s
#  45489 13658 infeasible   65         6.99507    5.94209  15.1%  40.5   45s
#  51496 14150    6.55142   68   71    6.99507    6.03231  13.8%  42.6   50s
#  62980 15654    6.60963   83   34    6.99507    6.09836  12.8%  42.8   55s
#  72658 19749    6.73252   73   39    6.99507    6.12786  12.4%  43.5   60s
#  80259 22166 infeasible   88         6.99507    6.12786  12.4%  45.1   65s
#  87205 24796    6.60725   69   65    6.99507    6.14629  12.1%  45.9   70s
#  97003 28917 infeasible   82         6.99507    6.17579  11.7%  45.6   75s
#  108486 33107    6.75051   84   42    6.99507    6.17579  11.7%  45.4   80s
#  116668 36516 infeasible   91         6.99507    6.17579  11.7%  45.9   85s
#  123166 39317 infeasible   85         6.99507    6.17579  11.7%  46.3   90s
#  130890 42331     cutoff   79         6.99507    6.17579  11.7%  46.8   95s
#  137959 45695    6.77957   90   31    6.99507    6.17579  11.7%  47.1  100s
#  145122 48794    6.63072   75   60    6.99507    6.17579  11.7%  47.3  105s
#  149071 49857    6.63675   75   56    6.99507    6.17579  11.7%  47.3  110s
#  155053 52857 infeasible   77         6.99507    6.17579  11.7%  47.5  115s
#  161360 55458    6.31228   70   90    6.99507    6.17579  11.7%  47.5  120s
#  168999 58468    6.79800   90   37    6.99507    6.17579  11.7%  47.5  125s
#  175001 61031     cutoff   91         6.99507    6.17579  11.7%  47.5  130s
#  182214 63795    6.17579   72   79    6.99507    6.17579  11.7%  47.5  135s
#  187620 65992    6.82795   89   38    6.99507    6.17579  11.7%  47.7  140s
#  195246 69157    6.33369   79   56    6.99507    6.17579  11.7%  47.8  145s
#  201308 71562    6.17579   64   76    6.99507    6.17579  11.7%  47.9  150s
#  208360 74238    6.63675   80   36    6.99507    6.17579  11.7%  47.9  155s
#  213215 76223 infeasible   97         6.99507    6.17579  11.7%  48.0  160s
# *217883 77659              89       6.9907947    6.17579  11.7%  48.1  163s
#  219911 78837    6.73252   76   42    6.99079    6.17579  11.7%  48.1  165s
#  226758 81533    6.17579   63   85    6.99079    6.17579  11.7%  48.2  170s
#  234759 84716    6.62468   76   55    6.99079    6.17579  11.7%  48.1  175s
#  242291 87667    6.94818   83   13    6.99079    6.17714  11.6%  48.0  180s
#  249044 90323    6.63675   73   69    6.99079    6.17934  11.6%  48.0  185s
#  255574 92741    6.92931   80   18    6.99079    6.18259  11.6%  48.0  190s
#  262831 95605    6.79241   72   37    6.99079    6.18660  11.5%  48.0  195s
#  270109 98232    6.81040   84   29    6.99079    6.19365  11.4%  47.9  200s
#  277411 101006    6.51137   70   67    6.99079    6.20213  11.3%  48.0  205s
#  282625 102891     cutoff   86         6.99079    6.20850  11.2%  48.1  210s
#  287481 104485    6.29273   73   79    6.99079    6.21585  11.1%  48.1  215s
#  291633 105896    6.69061   78   39    6.99079    6.21968  11.0%  48.1  220s
#  296229 107342 infeasible   77         6.99079    6.22373  11.0%  48.2  225s
#  300962 109037    6.94713   86   13    6.99079    6.22373  11.0%  48.2  230s
#  304942 110094 infeasible   89         6.99079    6.22373  11.0%  48.2  235s
#  312448 112773    6.38499   77   56    6.99079    6.22373  11.0%  47.9  240s
#  318051 114319    6.22373   74   85    6.99079    6.22373  11.0%  48.0  245s
#  322218 115498 infeasible   77         6.99079    6.22373  11.0%  48.3  250s
#  326598 116716    6.59232   86   53    6.99079    6.22373  11.0%  48.7  255s
#  330997 117695    6.31052   75   74    6.99079    6.22373  11.0%  49.0  260s
#  336310 118574    6.59474   78   51    6.99079    6.22373  11.0%  49.3  265s
#  338456 118911    6.67262   79   39    6.99079    6.22373  11.0%  49.5  270s
#  341910 119344 infeasible   77         6.99079    6.22373  11.0%  49.7  275s
#  342989 119363 infeasible   78         6.99079    6.22373  11.0%  49.7  280s
# H343047 119363                       6.9907947    6.22373  11.0%  49.7  280s
#  346602 119972    6.22373   69   73    6.99079    6.22373  11.0%  50.0  286s
#  350732 120940    6.22525   78   71    6.99079    6.22525  11.0%  50.2  290s
#  355149 122208    6.34900   79   70    6.99079    6.22922  10.9%  50.4  295s
#  360186 123866    6.89936   87   23    6.99079    6.23219  10.9%  50.4  300s
#  364896 124785    6.23492   63   29    6.99079    6.23492  10.8%  50.6  305s
#  370447 126701 infeasible   81         6.99079    6.24058  10.7%  50.6  310s
#  375016 127991 infeasible   75         6.99079    6.24621  10.7%  50.6  315s
#  380447 129603    6.70257   73   44    6.99079    6.24885  10.6%  50.6  320s
#  386247 131365 infeasible   82         6.99079    6.25311  10.6%  50.6  325s
#  391133 133087    6.54438   72   61    6.99079    6.25726  10.5%  50.6  330s
#  396234 134509    6.49953   72   55    6.99079    6.25953  10.5%  50.6  335s
#  401825 135964    6.67262   73   43    6.99079    6.26520  10.4%  50.7  340s
#  407536 137472    6.41578   73   57    6.99079    6.27156  10.3%  50.8  345s
#  411260 138304    6.64267   74   45    6.99079    6.27167  10.3%  50.9  350s
#  417543 140691 infeasible   71         6.99079    6.27476  10.2%  50.9  355s
#  422167 142113    6.30710   72   77    6.99079    6.27703  10.2%  50.9  364s
#  422179 142283    6.64267   73   61    6.99079    6.27711  10.2%  50.9  365s
#  428351 144074 infeasible   84         6.99079    6.27986  10.2%  50.9  370s
#  434559 145853    6.30710   72   56    6.99079    6.28597  10.1%  50.8  375s
#  439756 147311    6.70257   73   38    6.99079    6.29011  10.0%  50.9  380s
#  445360 148805    6.70257   77   43    6.99079    6.29515  10.0%  50.9  385s
#  451232 150796 infeasible   78         6.99079    6.30128  9.86%  50.9  390s
#  457394 153086    6.72056   76   37    6.99079    6.30694  9.78%  50.8  395s
#  463287 154326 infeasible   92         6.99079    6.30710  9.78%  50.8  401s
#  468669 155404 infeasible   77         6.99079    6.30710  9.78%  50.9  405s
#  472819 156168 infeasible   74         6.99079    6.30710  9.78%  51.0  410s
#  478863 157923    6.80952   80   31    6.99079    6.30710  9.78%  51.1  415s
#  483467 158825    6.33705   74   67    6.99079    6.30710  9.78%  51.1  420s
#  488927 160189    6.46343   74   74    6.99079    6.30710  9.78%  51.3  426s
#  494257 162018    6.36700   75   58    6.99079    6.30710  9.78%  51.3  430s
#  499859 163582    6.95925   82   28    6.99079    6.30710  9.78%  51.2  435s
#  506673 165535    6.76805   74   44    6.99079    6.30710  9.78%  51.2  440s
#  513994 167564    6.52221   80   47    6.99079    6.30710  9.78%  51.1  445s
#  519491 169047    6.78046   80   34    6.99079    6.30710  9.78%  51.1  450s
#  526240 170899    6.30710   73   74    6.99079    6.30710  9.78%  51.0  455s
#  531982 172638    6.80952   96   36    6.99079    6.30805  9.77%  51.1  460s
#  538784 174807     cutoff   89         6.99079    6.31024  9.73%  50.9  465s
#  544381 176439    6.97323   84   17    6.99079    6.31421  9.68%  50.9  470s
#  551647 178580    6.70257   77   50    6.99079    6.31906  9.61%  50.8  475s
#  555336 179264    6.76246   74   54    6.99079    6.31906  9.61%  50.9  480s
#  559773 180474 infeasible   84         6.99079    6.31961  9.60%  51.0  485s
#  565985 181629    6.45092   71   52    6.99079    6.31961  9.60%  51.0  490s
#  570200 182350    6.65463   77   39    6.99079    6.31961  9.60%  51.1  495s
#  571900 182993    6.31990   66   67    6.99079    6.31990  9.60%  51.1  500s
#  577325 184816    6.59232   72   55    6.99079    6.32360  9.54%  51.1  505s
#  581231 185914    6.84035   79   30    6.99079    6.32704  9.49%  51.1  510s
#  586674 187175    6.59474   72   54    6.99079    6.32891  9.47%  51.1  515s
#  593027 189297     cutoff   99         6.99079    6.33199  9.42%  51.1  520s
#  598167 190911    6.63675   80   59    6.99079    6.33433  9.39%  51.0  525s
#  603427 192434    6.85834   81    5    6.99079    6.33705  9.35%  51.0  530s
#  609994 194540    6.91779   77   38    6.99079    6.33705  9.35%  50.9  535s
#  616732 196378    6.33705   72   72    6.99079    6.33705  9.35%  50.9  540s
#  621853 197668    6.81040   79   31    6.99079    6.33705  9.35%  51.0  545s
#  627802 199360 infeasible   82         6.99079    6.33705  9.35%  51.0  550s
#  634486 201257 infeasible   83         6.99079    6.33705  9.35%  50.9  555s
#  640843 202981    6.72056   79   39    6.99079    6.33705  9.35%  50.9  560s
#  647346 204803 infeasible   75         6.99079    6.33705  9.35%  50.8  565s
#  654084 206782 infeasible   83         6.99079    6.33705  9.35%  50.8  570s
#  660174 208674 infeasible   80         6.99079    6.33705  9.35%  50.7  575s
#  666331 210713    6.62468   86   43    6.99079    6.33705  9.35%  50.6  580s
#  672585 212945    6.82795   78   41    6.99079    6.33705  9.35%  50.6  585s
#  679957 215048    6.67262   84   42    6.99079    6.33705  9.35%  50.5  590s
#  687078 217175 infeasible   79         6.99079    6.33705  9.35%  50.4  595s
#  692343 218554 infeasible   82         6.99079    6.33729  9.35%  50.4  600s
#  697399 219892 infeasible   80         6.99079    6.33813  9.34%  50.4  605s
#  703614 221635    6.63675   77   48    6.99079    6.33945  9.32%  50.3  610s
#  709657 223391    6.70257   78   26    6.99079    6.34266  9.27%  50.3  615s
#  712908 224301    6.79800   77   36    6.99079    6.34453  9.24%  50.3  622s
#  715056 225103    6.56927   77   73    6.99079    6.34565  9.23%  50.3  625s
#  721239 227082    6.38246   74   69    6.99079    6.34900  9.18%  50.3  630s
#  728355 229774 infeasible   81         6.99079    6.35305  9.12%  50.2  635s
#  734207 231448    6.98920   81   17    6.99079    6.35456  9.10%  50.2  640s
#  738739 231912    6.75051   75   38    6.99079    6.35504  9.09%  50.3  645s
#  741943 232247    6.40298   89   40    6.99079    6.35504  9.09%  50.5  650s
#  745580 232656    6.73252   77   29    6.99079    6.35504  9.09%  50.6  655s
#  750005 233539 infeasible   80         6.99079    6.35516  9.09%  50.7  660s
#  755186 234972    6.79845   83   19    6.99079    6.35548  9.09%  50.8  665s
#  761567 237172    6.76805   87   44    6.99079    6.36058  9.01%  50.7  670s
#  768257 239614    6.78046   84   27    6.99079    6.36506  8.95%  50.7  675s
#  774800 241633 infeasible   72         6.99079    6.36700  8.92%  50.7  680s
#  779818 242730    6.98920  100   21    6.99079    6.36700  8.92%  50.7  685s
#  785054 243839    6.65463   73   63    6.99079    6.36700  8.92%  50.8  690s
#  789446 245275 infeasible   75         6.99079    6.36700  8.92%  50.8  695s
#  795636 247403    6.70257   75   54    6.99079    6.36700  8.92%  50.8  700s
#  800975 249227    6.95925   85   20    6.99079    6.36700  8.92%  50.8  705s
#  807081 251098    6.36700   73   79    6.99079    6.36700  8.92%  50.8  710s
#  813353 252771    6.46343   74   77    6.99079    6.36700  8.92%  50.8  715s
#  818095 253884    6.36700   71   70    6.99079    6.36700  8.92%  50.8  720s
#  824860 255738    6.73252   76   34    6.99079    6.36700  8.92%  50.8  725s
#  832148 257640    6.95925   77   52    6.99079    6.36700  8.92%  50.7  730s
#  838803 259383    6.70257   78   53    6.99079    6.36700  8.92%  50.6  735s
#  844218 260739 infeasible   74         6.99079    6.36700  8.92%  50.6  740s
#  849786 262054    6.94818   92   17    6.99079    6.36700  8.92%  50.6  745s
#  853326 262566 infeasible   74         6.99079    6.36700  8.92%  50.6  752s
#  855709 263415 infeasible   80         6.99079    6.36700  8.92%  50.6  755s
#  860943 264910     cutoff   82         6.99079    6.36700  8.92%  50.6  761s
#  866513 266400    6.75051   83   28    6.99079    6.36700  8.92%  50.6  765s
#  873466 268264 infeasible   84         6.99079    6.36700  8.92%  50.5  770s
#  880655 270189    6.82795   78   47    6.99079    6.36700  8.92%  50.4  775s
#  887909 272369 infeasible   79         6.99079    6.36700  8.92%  50.3  780s
#  895890 274871    6.63675   71   54    6.99079    6.36887  8.90%  50.3  785s
#  903180 277598     cutoff   92         6.99079    6.37139  8.86%  50.2  790s
#  909491 279654 infeasible   81         6.99079    6.37309  8.84%  50.1  795s
#  916760 281801 infeasible   87         6.99079    6.37644  8.79%  50.1  800s
#  922994 283905    6.81040   78   34    6.99079    6.37976  8.74%  50.0  805s
#  929371 286088    6.79241   88   19    6.99079    6.38325  8.69%  50.0  810s
#  936152 286853 infeasible   77         6.99079    6.38348  8.69%  49.9  815s
#  942782 287138     cutoff   67         6.99079    6.38348  8.69%  49.9  820s
#  947266 287422 infeasible   78         6.99079    6.38499  8.67%  49.9  825s
#  951376 287560 infeasible   78         6.99079    6.38499  8.67%  50.0  830s
#  955771 288526    6.75051   80   40    6.99079    6.38543  8.66%  50.1  835s
#  962380 290172    6.78085   74   39    6.99079    6.39125  8.58%  50.1  840s
#  969434 292356    6.54553   69   73    6.99079    6.39522  8.52%  50.0  845s
#  976056 294010    6.79241   80   30    6.99079    6.39694  8.49%  49.9  850s
#  983918 295547    6.41780   69   68    6.99079    6.39694  8.49%  49.8  855s
#  991313 297537 infeasible   81         6.99079    6.40169  8.43%  49.8  860s
#  995522 297735 infeasible   82         6.99079    6.40298  8.41%  49.9  865s
#  996059 297807 infeasible   76         6.99079    6.40310  8.41%  49.9  872s
#  999395 298867 infeasible   80         6.99079    6.40504  8.38%  49.9  875s
#  1007460 301031     cutoff   89         6.99079    6.41438  8.25%  49.8  880s
#  1010740 301076 infeasible   77         6.99079    6.41494  8.24%  49.9  885s
#  1013876 301099    6.61876   82   57    6.99079    6.41494  8.24%  50.0  890s
#  1020162 302477    6.55931   76   78    6.99079    6.41537  8.23%  50.1  896s
#  1024641 303828    6.97583   82   34    6.99079    6.41933  8.17%  50.0  900s
#  1031070 305612    6.70257   78   44    6.99079    6.42190  8.14%  50.0  905s
#  1037076 306658 infeasible   77         6.99079    6.42689  8.07%  49.9  910s
#  1042202 307687    6.76246   76   32    6.99079    6.42689  8.07%  49.9  915s
#  1047612 308898    6.42689   67   59    6.99079    6.42689  8.07%  49.9  920s
#  1052105 309947    6.76246   78   51    6.99079    6.42689  8.07%  50.0  925s
#  1058558 311482    6.59232   77   66    6.99079    6.43003  8.02%  50.0  930s
#  1064820 312956    6.86027   88   27    6.99079    6.43573  7.94%  49.9  935s
#  1071241 314506    6.98920   81   34    6.99079    6.44325  7.83%  49.9  940s
#  1078357 316971    6.87995   84   37    6.99079    6.44850  7.76%  49.8  945s

# %% [markdown]
# 讓model運算180秒過後的結果，依據線性化切段個數的改變，解的品質如圖所示，第一張圖是目標式值的改變，第二章圖是gap的改變

# %%
plt.plot(objs)

# %%
plt.plot(gaps)

# %% [markdown]
# 讓model運算直到達到gap < 0.04，依據線性化切段個數的改變，所花的時間如圖所示

# %%
plt.plot(ts)

# %% [markdown]
# **隨著num of break point上升得到的objective value，x軸由25起算
# 隨著對ln的精準度越高，objective value上升，因為原本用內插法就會低估了。**

# %%
plt.plot(objs)

# %% [markdown]
# **隨著num of break point上升得到的execute time，x軸由25起算
# 隨著對ln的精準度越高，執行速度變得更快。**

# %%
model.MIPGap
