# %%
from pandas.core.indexes import datetimes
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import gurobipy as gp
import pandas as pd

# %% [markdown]
# # 1. (30%) Consider a production company who owns 3 plants to produce 2 consumer goods. If the available capacity and its uses are given in the following table, try to find an Efficient Set of product mixes if maximal profit and minimal pollution penalty are considered by using (Wang, 2004)
# 題目假設：
# 製作 1 單位 product1 需要 1 單位 plant1 及 3 單位 plant 3
# 製作 1 單位 product2 需要 2 單位 plant2 及 2 單位 plant 3

# %% [markdown]
# ## (a) Graphical solution by the “Concept of Dominance”
#
# 模型列式：
# maximun profit: $$Max: 3x_1 + 5x_2$$
# minimun penalty: $$Min: 3x_1 + 4x_2$$
#
#
# $s.t.$
# $$x_1 ≤ 4$$
# $$2x_2 ≤ 12$$
# $$3x_1+2x_2 ≤ 18$$
# $$x_1, x_2 ≥ 0$$
#
# ![IMG_0491B5EEB057-1.jpeg](attachment:8e9eb13d-ae23-4469-a7cb-63d4b8081910.jpeg)

# %% [markdown]
# ## (b) Weighting method with weights 2:1 w.r.t. objectives of profit and penalty
# #### model:
#
# $$Max: W_1(3x_1+5x_2)-W_2(2x_1+4x_2)$$
# $s.t.$
# $$x_1 ≤ 4$$
# $$2x_2 ≤ 12$$
# $$3x_1+2x_2 ≤ 18$$
# $$x_1, x_2 ≥ 0$$
# $$W_1=2, W_2=1$$

# %%
W = [2, 1]

w_method = gp.Model("W_method")
x1 = w_method.addVar(vtype=gp.GRB.CONTINUOUS,name="x1", lb=0)
x2 = w_method.addVar(vtype=gp.GRB.CONTINUOUS,name="x2", lb=0)
w_method.update()

w_method.setObjective(W[0]*(3*x1 + 5*x2) - W[1]*(2*x1 + 4*x2), gp.GRB.MAXIMIZE)

w_method.addConstr(x1 <= 4)
w_method.addConstr(2*x2 <= 12)
w_method.addConstr(3*x1 + 2*x2 <= 18)

w_method.optimize()
# Out:
# Academic license - for non-commercial use only - expires 2021-07-12
# Using license file /Users/tungwu/gurobi.lic
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 3 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0x11ca3af7
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [4e+00, 6e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+01]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 2 columns, 2 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.4000000e+01   1.500000e+00   0.000000e+00      0s
#        1    4.4000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds
# Optimal objective  4.400000000e+01

# %%
w_obj = w_method.objVal
w_x = w_method.x
w_profit = (3*w_x[0] + 5*w_x[1])
w_penalty = (2*w_x[0] + 4*w_x[1])

print("when (profit : penalty) is (2 : 1)\n")
print("\tprofit is: %d" %w_profit)
print("\tpenalty is: %d" %w_penalty)
print("\tEfficient Set is: (%f, %f)" %(w_x[0], w_x[1]))
# Out:
# when (profit : penalty) is (2 : 1)
#
# 	profit is: 36
# 	penalty is: 28
# 	Efficient Set is: (2.000000, 6.000000)

# %% [markdown]
# ## (c) 𝜀 −Constraint Method with r = 2
# set maximun profit as first objective, penalty obj as rest k(=1) objective.
# BTW, since there're too less option to chose when r = 2
# we chose r = 3 to get one more option to suggest.
# (note: when t=0 or 2,  r=3 is equal to r=2, t=0 or 1 respectively

# %%
f_panalty = gp.Model("f_panalty")

x1 = f_panalty.addVar(vtype=gp.GRB.CONTINUOUS,name="x1", lb=0)
x2 = f_panalty.addVar(vtype=gp.GRB.CONTINUOUS,name="x2", lb=0)
f_panalty.update()

f_panalty.setObjective(-(2*x1 + 4*x2), gp.GRB.MAXIMIZE)

f_panalty.addConstr(x1 <= 4)
f_panalty.addConstr(2*x2 <= 12)
f_panalty.addConstr(3*x1 + 2*x2 <= 18)

f_panalty.optimize()

f_panalty_min = gp.Model("f_panalty")

x1 = f_panalty_min.addVar(vtype=gp.GRB.CONTINUOUS,name="x1", lb=0)
x2 = f_panalty_min.addVar(vtype=gp.GRB.CONTINUOUS,name="x2", lb=0)
f_panalty_min.update()

f_panalty_min.setObjective(-(2*x1 + 4*x2), gp.GRB.MINIMIZE)

f_panalty_min.addConstr(x1 <= 4)
f_panalty_min.addConstr(2*x2 <= 12)
f_panalty_min.addConstr(3*x1 + 2*x2 <= 18)

f_panalty_min.optimize()
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 3 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0xa5244240
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+01]
# Presolve removed 3 rows and 2 columns
# Presolve time: 0.01s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.01 seconds
# Optimal objective -0.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 3 rows, 2 columns and 4 nonzeros
# Model fingerprint: 0xe1ea874a
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+00]
#   Objective range  [2e+00, 4e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+01]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 1 rows, 2 columns, 2 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -3.6000000e+01   1.500000e+00   0.000000e+00      0s
#        1   -2.8000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds
# Optimal objective -2.800000000e+01

# %%
R = 3
T = np.arange(R)
c_methods = []
for t in T:
    c_methods.append(gp.Model("W_method"))
    e = f_panalty_min.objVal + (t / (R-1))*(f_panalty.objVal - f_panalty_min.objVal)
    x1 = c_methods[t].addVar(vtype=gp.GRB.CONTINUOUS,name="x1", lb=0)
    x2 = c_methods[t].addVar(vtype=gp.GRB.CONTINUOUS,name="x2", lb=0)
    c_methods[t].update()

    c_methods[t].setObjective(W[0]*(3*x1 + 5*x2) - W[1]*(2*x1 + 4*x2), gp.GRB.MAXIMIZE)

    c_methods[t].addConstr(-(2*x1 + 4*x2) >= e)
    c_methods[t].addConstr(x1 <= 4)
    c_methods[t].addConstr(2*x2 <= 12)
    c_methods[t].addConstr(3*x1 + 2*x2 <= 18)

    c_methods[t].optimize()
    print("\n\n===========\n\n")
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x873002ba
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [4e+00, 6e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 3e+01]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.01s
# Presolved: 2 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.6000000e+01   1.600000e+01   0.000000e+00      0s
#        2    4.4000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 2 iterations and 0.01 seconds
# Optimal objective  4.400000000e+01
#
#
# ===========
#
#
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x3879c27f
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [4e+00, 6e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+01]
# Presolve removed 2 rows and 0 columns
# Presolve time: 0.00s
# Presolved: 2 rows, 2 columns, 4 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.8000000e+01   3.750000e+00   0.000000e+00      0s
#        1    2.5000000e+01   0.000000e+00   0.000000e+00      0s
#
# Solved in 1 iterations and 0.01 seconds
# Optimal objective  2.500000000e+01
#
#
# ===========
#
#
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 4 rows, 2 columns and 6 nonzeros
# Model fingerprint: 0x49a9aa0d
# Coefficient statistics:
#   Matrix range     [1e+00, 4e+00]
#   Objective range  [4e+00, 6e+00]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [4e+00, 2e+01]
# Presolve removed 4 rows and 2 columns
# Presolve time: 0.00s
# Presolve: All rows and columns removed
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0   -0.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 0 iterations and 0.00 seconds
# Optimal objective -0.000000000e+00
#
#
# ===========

# %%
print([c_methods[t].objVal for t in T])
print([c_methods[t].x for t in T])
# Out:
# [44.0, 25.0, -0.0]
# [[2.0, 6.0], [4.0, 1.5], [0.0, 0.0]]

# %%
print("when r = 3\n")
for t in T:
    c_profit = c_methods[t].objVal
    c_penalty = 2*c_methods[t].x[0] + 4*c_methods[t].x[1]
    print("\twhen t = %d" %t)
    print("\tprofit is: %d" %c_profit)
    print("\tpenalty is: %d" %c_penalty)
    print("\tEfficient Set is: (%f, %f)" %(c_methods[t].x[0], c_methods[t].x[1]))
    print()
# Out:
# when r = 3
#
# 	when t = 0
# 	profit is: 44
# 	penalty is: 28
# 	Efficient Set is: (2.000000, 6.000000)
#
# 	when t = 1
# 	profit is: 25
# 	penalty is: 14
# 	Efficient Set is: (4.000000, 1.500000)
#
# 	when t = 2
# 	profit is: 0
# 	penalty is: 0
# 	Efficient Set is: (0.000000, 0.000000)

# %% [markdown]
# # 2. (20%) Discuss the efficient sets from the following graph of two criteria: (Wang, 2004)
#
# ![截圖 2021-05-21 下午3.18.56.png](attachment:8a3057a8-c2cf-4c10-9f00-2305f083f029.png)

# %% [markdown]
# ##### Ans:
# 當 C1, C2 線分別往最大化的法向量（箭頭方向）移動時，同時處於兩線的重疊區域，稱之 dominant cone，如可行解域有解能處在 cone 的焦點處，且當時的 cone 之內沒有其他可行解，則該點可不被其他鄰近的點 dominate，我們稱該點為 dominant point，其集合稱為 efficient sets，此題的 dominant cone 如下：
#
# ![IMG_79724D6F1736-1.jpeg](attachment:c68b1be5-5b5e-482d-bca4-c6071e2db8cd.jpeg)

# %% [markdown]
# 而左圖的 dominant set 如下藍色筆跡所描：
#
#
# ![IMG_D14FE02BF2F2-1.jpeg](attachment:36d4b1f3-dc65-4bff-a16d-2f420d92a087.jpeg)

# %% [markdown]
# 右圖的 dominant set 如下藍色筆跡所描：
# ![IMG_423C4905F39E-1.jpeg](attachment:57a87360-35c5-4e16-997c-cccbe0102c58.jpeg)

# %% [markdown]
# # 3. (50%) Data Envelopment Analysis (DEA)

# %% [markdown]
# ## (a) Define the decision variables and LP formulation
# #### **CRS** model for each $DMU_r$,
# - decision variables:
#     - $v^r_i :$ weight of input $i$ each $DMU_r$ hold,  $i: {(Personnel, Expenses (unit:1000), Space)}$
#     - $u^r_j :$ weight of output $j$ each $DMU_r$ hold,  $j: {(Teaching, Publications, Grants (unit:1000))}$
#
#
# - LP formulation:
#     - $K: $ DMU sets
#     - $x^k_i: $ input $i$ for $DMU_k$, $i \in I: {(Personnel, Expenses (unit:1000), Space)}$
#     - $y^k_j: $ output $i$ for $DMU_k$, $j \in J: {(Teaching, Publications, Grants (unit:1000))}$
#     - model:$$Max: \sum_{j \in J}(u^r_j * y^r_j)$$
#     $s.t.$
#     $$\sum_{i \in I}(v^r_i * x^r_i) = 1$$
#     $$\sum_{j \in J}(u^r_j * y^k_j - \sum_{i \in I}(v^r_i * x^k_i) ≤ 1 , \text{for } k \in K$$
#     $$v^r_j, u^r_j ≥ 0$$
#     $$j \in J, i \in I$$
#
# #### **VRS** model for each $DMU_r$,
# - decision variables:
#     - $v^r_i :$ weight of input $i$ each $DMU_r$ hold,  $i: {(Personnel, Expenses (unit:1000), Space)}$
#     - $u^r_j :$ weight of output $j$ each $DMU_r$ hold,  $j: {(Teaching, Publications, Grants (unit:1000))}$
#     - $u^r_0: $ 允許生產函數不必通過原點，可用來判斷規模報酬型態
#         - $u^r_0=0: $ 為固定規模報酬(CRS)
#         - $u^r_0<0: $ 為規模報酬遞增(IRS)
#         - $u^r_0>0: $ 為規模報酬遞減(DRS)
#
#
# - LP formulation:
#     - $K: $ DMU sets
#     - $x^k_i: $ input $i$ for $DMU_k$, $i \in I: {(Personnel, Expenses (unit:1000), Space)}$
#     - $y^k_j: $ output $i$ for $DMU_k$, $j \in J: {(Teaching, Publications, Grants (unit:1000))}$
#     - model:$$Max: \sum_{j \in J}(u^r_j * y^r_j) - u^r_0$$
#     $s.t.$
#     $$\sum_{i \in I}(v^r_i * x^r_i) = 1$$
#     $$\sum_{j \in J}(u^r_j * y^k_j - \sum_{i \in I}(v^r_i * x^k_i) - u^r_0 ≤ 1 , \text{for } k \in K$$
#     $$v^r_j, u^r_j ≥ 0$$
#     $$j \in J, i \in I$$

# %%
data = pd.read_excel("ORA_Assignment_04_DEA.xlsx", header=0)

# %%
SCHOOLS = [item for item in data["School"] if isinstance(item, str)]

# %%
SCHOOL_DATA = {}
schools, deps = [], []
for index, row in data.iterrows():
    if isinstance(row["School"], str):
        school = row["School"]
        SCHOOL_DATA[school] = pd.DataFrame(data=None, columns=data.columns[1:])b
    else:
        SCHOOL_DATA[school] = SCHOOL_DATA[school].append(pd.DataFrame(pd.DataFrame(data=row[1:]).T, columns=data.columns[1:]))
        schools.append(school)
        deps.append(row["Department"])

# %%
IDX = pd.MultiIndex.from_arrays([schools, deps], names=["School", "Department"])
collect = pd.concat([SCHOOL_DATA[school].iloc[:] for school in SCHOOLS]).drop(["Department"], axis=1)
VALUE_DATA = pd.DataFrame(data=np.array(collect), columns=collect.columns, index=IDX)
VALUE_DATA.head()
# Out:
#                                Personnel Expenses (unit:1000) Space Teaching  \
# School       Department
# Liberal Arts Chinese                33.5               6079.5  5376    26131
#              Foreign Languages      36.5               8387.4  4574    40105
#              History                  26               5104.8  3795    13678
#              Arts                      6               3420.6  1610     4926
# Sciences     Mathematics            29.5               6426.2  4175    23647
#
#                                Publications Grants (unit:1000)
# School       Department
# Liberal Arts Chinese                      5             4250.9
#              Foreign Languages            0             1543.5
#              History                      0             1729.1
#              Arts                         0             3562.2
# Sciences     Mathematics                 27            10518.6

# %%
I = 3
O = 3
INPUTS = [i for i in  data.columns[2:2+I]]
OUTPUTS = [o for o in  data.columns[2+I:2+I+O]]

# %%
for index, row in SCHOOL_DATA[SCHOOLS[0]].iterrows():
    print([row[i] for i in INPUTS])
    print()
# Out:
# [33.5, 6079.5, 5376.0]
#
# [36.5, 8387.4, 4574.0]
#
# [26.0, 5104.8, 3795.0]
#
# [6.0, 3420.6, 1610.0]

# %%
DMU = []
X = {}
Y = {}
for s in SCHOOLS:
    for index, row in SCHOOL_DATA[s].iterrows():
        DMU = DMU + [row.iloc[0]]
        X[row.iloc[0]] = [i for i in row.iloc[1:4]]
        Y[row.iloc[0]] = [o for o in row.iloc[4:]]

# %%
record = {}  

## cal technical efficiency (VRS) and scale efficiency (CRS) for each DMU
for r in DMU:            
    
    ## VRS
    vrs_model=gp.Model("VRS_model")
    
    ## add variables
    vrs_v, vrs_u,u0={},{},{}
    for i in range(I):
        vrs_v[r,i]=vrs_model.addVar(vtype=gp.GRB.CONTINUOUS,name="%s"%(INPUTS[i]))
    
    for j in range(O):
        vrs_u[r,j]=vrs_model.addVar(vtype=gp.GRB.CONTINUOUS, name="%s"%(OUTPUTS[j]))
    u0[r]=vrs_model.addVar(lb=-1000,vtype=gp.GRB.CONTINUOUS, name="u_0")
    
    vrs_model.update()
    
    ## objective
    vrs_model.setObjective(gp.quicksum(vrs_u[r,j]*Y[r][j] for j in range(O))-u0[r],gp.GRB.MAXIMIZE)
    
    ## add constraints
    vrs_model.addConstr(gp.quicksum(vrs_v[r,i]*X[r][i] for i in range(I))==1)
    for k in DMU:
        vrs_model.addConstr(gp.quicksum(vrs_u[r,j]*Y[k][j] for j in range(O))-gp.quicksum(vrs_v[r,i]*X[k][i] for i in range(I))-u0[r] <=0)
    
    ## solve
    vrs_model.optimize()
    
    ## cal scale efficiency (CRS) for each dmu    
    crs_model=gp.Model("CRS_model")
    
    ## add variables
    crs_v, crs_u = {},{}
    for i in range(I):
        crs_v[r,i]=crs_model.addVar(vtype=gp.GRB.CONTINUOUS,name="v_%s%d"%(r,i))
    
    for j in range(O):
        crs_u[r,j]=crs_model.addVar(vtype=gp.GRB.CONTINUOUS,name="u_%s%d"%(r,j))
    
    crs_model.update()
    
    ## objective
    crs_model.setObjective(gp.quicksum(crs_u[r,j] * Y[r][j] for j in range(O)), gp.GRB.MAXIMIZE)
    
    ## add constraints
    crs_model.addConstr(gp.quicksum(crs_v[r,i] * X[r][i] for i in range(I)) == 1)
    for k in DMU:
        crs_model.addConstr(gp.quicksum(crs_u[r,j]*Y[k][j] for j in range(O)) - gp.quicksum(crs_v[r,i]*X[k][i] for i in range(I)) <= 0)
    
    ## solve
    crs_model.optimize()
    
    record[r] = np.round([v.x for v in vrs_model.getVars()] + [vrs_model.objVal] + [crs_model.objVal], 6)
# Out:
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xd1a9ea3b
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 3e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1537676e+32   4.699710e+31   1.153768e+02      0s
#        7    9.6828152e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  9.682815161e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x4574a645
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [5e+00, 3e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1537676e+32   5.066194e+31   1.153768e+02      0s
#        7    9.3593874e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  9.359387371e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x63ffb124
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 249 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.5967480e+32   3.746828e+31   1.596748e+02      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.02 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xae89ce09
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+03, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 5 columns, 208 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.7002007e+01   2.245930e+01   0.000000e+00      0s
#        4    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.02 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x7ea66e6d
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 249 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.6806836e+31   3.746828e+31   5.680684e+01      0s
#        9    6.6091489e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  6.609148873e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x0f0bfdc5
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+03, 1e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 5 columns, 208 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.9034786e+01   2.513766e+01   0.000000e+00      0s
#        5    5.6798285e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.02 seconds
# Optimal objective  5.679828466e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x1d61d14c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 5e+03]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 249 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.6199609e+31   3.746828e+31   2.619961e+01      0s
#        9    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x980038ce
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+03, 5e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.01s
# Presolved: 42 rows, 5 columns, 208 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3510252e+01   2.467898e+01   0.000000e+00      0s
#        6    7.7004248e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds
# Optimal objective  7.700424779e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x189cdcb5
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3991523e+32   4.699710e+31   1.399152e+02      0s
#        9    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x7caf9d28
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [3e+01, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3991523e+32   5.066194e+31   1.399152e+02      0s
#       10    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x5c22926d
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 6e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9283281e+32   4.465158e+31   2.928328e+02      0s
#       15    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 15 iterations and 0.06 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x0d817241
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [7e+01, 6e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.9283281e+32   4.831641e+31   2.928328e+02      0s
#        9    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.02 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xe0f469b9
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.02s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1116680e+32   4.699710e+31   2.111668e+02      0s
#       12    8.1182346e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.03 seconds
# Optimal objective  8.118234626e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xbc5d38db
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [5e+01, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.1116680e+32   5.066194e+31   2.111668e+02      0s
#        9    8.0480288e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.02 seconds
# Optimal objective  8.048028761e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xea07a672
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 5e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3112168e+32   4.699710e+31   1.311217e+02      0s
#       11    7.9127394e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.02 seconds
# Optimal objective  7.912739402e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xc7375b4c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+01, 5e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.3112168e+32   5.066194e+31   1.311217e+02      0s
#        9    7.1762635e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.02 seconds
# Optimal objective  7.176263542e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x5bf91094
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.7741797e+31   4.699710e+31   9.774180e+01      0s
#        9    7.1165761e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  7.116576062e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xdc5947f3
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+01, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.7741797e+31   5.066194e+31   9.774180e+01      0s
#        8    6.6528010e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  6.652800983e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x06adac98
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1432422e+31   4.465158e+31   4.143242e+01      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.02 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xaef0d2cd
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [6e+00, 1e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1432422e+31   4.831641e+31   4.143242e+01      0s
#        8    6.3299107e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.02 seconds
# Optimal objective  6.329910700e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x44ad9f9d
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 8e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9050332e+32   4.699710e+31   3.905033e+02      0s
#        7    8.5485320e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.02 seconds
# Optimal objective  8.548532020e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xa1e873c1
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [9e+01, 8e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9050332e+32   5.066194e+31   3.905033e+02      0s
#        9    8.5298205e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.02 seconds
# Optimal objective  8.529820519e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xaf1f3aa6
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.5696133e+32   4.699710e+31   6.569613e+02      0s
#       10    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xa973ab25
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+02, 2e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.5696133e+32   5.066194e+31   6.569613e+02      0s
#       11    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.02 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xde0cc7ed
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7613848e+32   4.699710e+31   1.761385e+02      0s
#       11    9.8155899e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  9.815589884e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xa7cd93fa
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [5e+01, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7613848e+32   5.066194e+31   1.761385e+02      0s
#       11    9.6256361e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  9.625636100e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xd16856cc
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 6e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4560781e+32   4.699710e+31   3.456078e+02      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x2d528bba
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+02, 6e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.4560781e+32   5.066194e+31   3.456078e+02      0s
#        4    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x862077e9
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 3e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1724473e+32   4.699710e+31   1.172447e+02      0s
#       11    6.4079944e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  6.407994442e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x2c476cd3
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+01, 3e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1724473e+32   5.066194e+31   1.172447e+02      0s
#        8    5.6808879e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  5.680887873e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x219b8a7d
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+05]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.5672461e+32   4.465158e+31   3.567246e+02      0s
#        8    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x45a81897
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+02, 1e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.5672461e+32   4.831641e+31   3.567246e+02      0s
#        5    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x418e9b8d
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 5e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3487383e+32   4.699710e+31   2.348738e+02      0s
#       11    7.9264297e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.09 seconds
# Optimal objective  7.926429719e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x3f9b146e
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [3e+01, 5e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.3487383e+32   5.066194e+31   2.348738e+02      0s
#       12    7.8608833e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 12 iterations and 0.01 seconds
# Optimal objective  7.860883281e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x04a51b38
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9086895e+32   4.699710e+31   3.908689e+02      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xb1392e68
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+01, 2e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.9086895e+32   5.066194e+31   3.908689e+02      0s
#        5    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x95310af0
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7765137e+32   4.699710e+31   1.776514e+02      0s
#       11    8.0654497e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  8.065449725e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x9c548742
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7765137e+32   5.066194e+31   1.776514e+02      0s
#        8    8.0008992e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  8.000899194e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xaecd6c20
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8818301e+32   4.699710e+31   1.881830e+02      0s
#       11    7.8148134e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  7.814813420e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xb8eb5847
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [3e+01, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.8818301e+32   5.066194e+31   1.881830e+02      0s
#        9    7.5976677e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  7.597667743e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x69e4b0b3
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 3e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2742344e+32   4.699710e+31   1.274234e+02      0s
#       11    7.0588480e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  7.058847991e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xdd2ba721
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [3e+01, 3e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2742344e+32   5.066194e+31   1.274234e+02      0s
#        7    6.0854133e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  6.085413252e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x8b925a25
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 249 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2403652e+32   3.912240e+31   1.240365e+02      0s
#        6    8.3002732e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds
# Optimal objective  8.300273246e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xe2542fde
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+04, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 5 columns, 208 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.7357866e+01   2.516861e+01   0.000000e+00      0s
#       10    7.8354584e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.01 seconds
# Optimal objective  7.835458363e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xbd372ac0
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.4936133e+31   4.699710e+31   6.493613e+01      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xc4ae47c2
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.4936133e+31   5.066194e+31   6.493613e+01      0s
#        8    9.8631788e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  9.863178847e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xec5bb320
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+05]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.08s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.4073008e+32   4.699710e+31   4.407301e+02      0s
#        9    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.09 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xaf8dadda
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [7e+01, 2e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.4073008e+32   5.066194e+31   4.407301e+02      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x10c9e5ff
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 9e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4773965e+32   4.465158e+31   2.477396e+02      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xa40389e7
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+01, 9e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.4773965e+32   4.831641e+31   2.477396e+02      0s
#        3    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.02 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x0a44b0ae
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1508262e+32   4.699710e+31   1.150826e+02      0s
#       11    7.3867345e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.02 seconds
# Optimal objective  7.386734461e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xf8bf4895
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+00, 4e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.02s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1508262e+32   5.066194e+31   1.150826e+02      0s
#        7    6.5954272e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.03 seconds
# Optimal objective  6.595427189e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x60178d2e
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.7016797e+31   4.465158e+31   5.701680e+01      0s
#        6    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x5bc5e0e3
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+01, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    5.7016797e+31   4.831641e+31   5.701680e+01      0s
#        6    8.2264729e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds
# Optimal objective  8.226472921e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xd9661753
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 3e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1707188e+32   4.465158e+31   1.170719e+02      0s
#        5    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.02 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x49d33635
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+01, 3e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1707188e+32   4.831641e+31   1.170719e+02      0s
#        3    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x13a4b149
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2123770e+32   4.699710e+31   1.212377e+02      0s
#       13    7.5041687e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 13 iterations and 0.01 seconds
# Optimal objective  7.504168706e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xfbf50c01
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+01, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2123770e+32   5.066194e+31   1.212377e+02      0s
#        9    7.0213619e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  7.021361875e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x92abbc31
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.0633594e+31   4.699710e+31   9.063359e+01      0s
#       11    7.3005247e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 11 iterations and 0.01 seconds
# Optimal objective  7.300524701e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xcec90a8b
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+01, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.01s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    9.0633594e+31   5.066194e+31   9.063359e+01      0s
#        9    6.3139626e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  6.313962614e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xc4db465b
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 3e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7090430e+32   4.699710e+31   1.709043e+02      0s
#        8    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xb3388ca1
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+00, 3e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.7090430e+32   5.066194e+31   1.709043e+02      0s
#        6    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x72de3bad
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.1307812e+31   4.465158e+31   7.130781e+01      0s
#        9    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x4ce5bb73
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [2e+00, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.1307812e+31   4.831641e+31   7.130781e+01      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xeadedac1
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7339453e+31   4.699710e+31   6.733945e+01      0s
#        8    7.7407246e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  7.740724599e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xebc3d2d3
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+00, 1e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.7339453e+31   5.066194e+31   6.733945e+01      0s
#        7    6.8874167e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  6.887416660e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x63bffafc
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 3e+05]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2121426e+33   4.465158e+31   1.212143e+03      0s
#        7    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x4a290b31
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+02, 3e+05]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.2121426e+33   4.831641e+31   1.212143e+03      0s
#        4    9.6336817e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 4 iterations and 0.01 seconds
# Optimal objective  9.633681721e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x347e6272
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 6e+03]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1435742e+31   4.465158e+31   4.143574e+01      0s
#        8    5.9056245e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  5.905624479e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xe47fd484
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [6e+00, 6e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.1435742e+31   4.831641e+31   4.143574e+01      0s
#        8    4.3319812e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  4.331981181e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x4d5684d0
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.4418555e+31   4.699710e+31   8.441855e+01      0s
#        9    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 9 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x6196f76c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+01, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    8.4418555e+31   5.066194e+31   8.441855e+01      0s
#        7    8.5852354e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  8.585235392e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xb4cc7623
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 4e+03]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2628516e+31   4.465158e+31   2.262852e+01      0s
#        8    7.7150228e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  7.715022825e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x10f4d872
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [4e+00, 4e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2628516e+31   4.831641e+31   2.262852e+01      0s
#        6    4.5376249e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 6 iterations and 0.01 seconds
# Optimal objective  4.537624871e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x4c754cf5
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 5e+03]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.03s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2734961e+31   4.465158e+31   3.273496e+01      0s
#        8    8.0274054e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.03 seconds
# Optimal objective  8.027405379e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xcabbed1c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [6e+00, 5e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.2734961e+31   4.831641e+31   3.273496e+01      0s
#        5    5.2878889e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds
# Optimal objective  5.287888858e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xe76f530d
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 2e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 249 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    6.8848047e+31   3.746828e+31   6.884805e+01      0s
#        5    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x72240205
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+03, 2e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 5 columns, 208 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.2717419e+01   1.791349e+01   0.000000e+00      0s
#        5    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 5 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0xef0c6a03
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 1e+04]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 7 columns, 284 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.4217578e+31   4.699710e+31   4.421758e+01      0s
#        8    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 8 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0x6a7e7c7c
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [6e+00, 1e+04]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 243 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    4.4217578e+31   5.066194e+31   4.421758e+01      0s
#       10    8.0871363e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 10 iterations and 0.01 seconds
# Optimal objective  8.087136272e-01
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 7 columns and 284 nonzeros
# Model fingerprint: 0x7a392d92
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+00, 6e+03]
#   Bounds range     [1e+03, 1e+03]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 6 columns, 249 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    2.5900586e+31   3.746828e+31   2.590059e+01      0s
#        3    1.0000000e+00   0.000000e+00   0.000000e+00      0s
#
# Solved in 3 iterations and 0.01 seconds
# Optimal objective  1.000000000e+00
# Gurobi Optimizer version 9.1.2 build v9.1.2rc0 (mac64)
# Thread count: 8 physical cores, 8 logical processors, using up to 8 threads
# Optimize a model with 42 rows, 6 columns and 243 nonzeros
# Model fingerprint: 0xb5db7fbe
# Coefficient statistics:
#   Matrix range     [1e+00, 3e+05]
#   Objective range  [1e+03, 6e+03]
#   Bounds range     [0e+00, 0e+00]
#   RHS range        [1e+00, 1e+00]
# Presolve removed 0 rows and 1 columns
# Presolve time: 0.00s
# Presolved: 42 rows, 5 columns, 208 nonzeros
#
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    1.1498508e+01   2.757815e+01   0.000000e+00      0s
#        7    7.3603496e-01   0.000000e+00   0.000000e+00      0s
#
# Solved in 7 iterations and 0.01 seconds
# Optimal objective  7.360349633e-01

# %%
def judge_RS(u0):
    if u0 > 0:
        return "DRS"
    elif u0 < 0:
        return "IRS"
    return "CRS"

# %% [markdown]
# ## (b) Show the results of overall efficiency (OE, CRS model), technical efficiency (TE, VRS model), scale efficiency (SE)

# %%
col = [v.varName for v in vrs_model.getVars()] + ["TE", "OE"]
result = pd.DataFrame(data=record).T
result.columns = col
result["SE"] = np.round(result["OE"] / result["TE"], 3)
result["return to scale"] = [judge_RS(u0=u0) for u0 in result["u_0"]]
result = result.set_index(keys=IDX)
result
# Out:
#                                       Personnel  Expenses (unit:1000)  \
# School          Department
# Liberal Arts    Chinese                0.000000              0.000164
#                 Foreign Languages      0.000000              0.000000
#                 History                0.000000              0.000196
#                 Arts                   0.164011              0.000000
# Sciences        Mathematics            0.000000              0.000141
#                 Physics                0.000000              0.000096
#                 Chemistry              0.028413              0.000000
#                 Earth Sciences         0.046929              0.000020
#                 Biology                0.051698              0.000006
#                 Biotechnology          0.000000              0.000000
# Engineering     Mechanical Eng.        0.000000              0.000070
#                 Electrical Eng.        0.017606              0.000000
#                 Information Eng.       0.055340              0.000000
#                 Chemical Eng.          0.008617              0.000054
#                 Resources Eng.         0.026376              0.000057
#                 Materials Eng.         0.038462              0.000000
#                 Civil Eng.             0.028214              0.000001
#                 Hydraulic Eng.         0.036364              0.000000
#                 Architecture           0.035088              0.000000
#                 Engineering Science    0.036805              0.000000
#                 Naval Architecture     0.035657              0.000053
#                 Urban Planning         0.055049              0.000005
#                 Industrial Design      0.080000              0.000000
#                 Aeronautical Eng.      0.000000              0.000115
#                 Environmental Eng.     0.049811              0.000000
#                 Surveying Eng.         0.045606              0.000036
#                 Manufacturing Eng.     0.119548              0.000000
#                 Biomedical Eng.        0.100000              0.000000
# Management      Industrial Mgmt.       0.018578              0.000068
#                 Transportation Mgmt.   0.030573              0.000073
#                 Business Admin.        0.029031              0.000000
#                 Accountancy            0.066667              0.000000
#                 Statistics             0.000000              0.000239
# Medicine        Medicine               0.000000              0.000025
#                 Nursing                0.008559              0.000000
#                 Medical Technology     0.000000              0.000050
#                 Occupational Therapy   0.054852              0.000154
#                 Physical Therapy       0.048211              0.000152
# Social Sciences Political Economy      0.000000              0.000000
#                 Education              0.000000              0.000548
#                 Law                    0.000000              0.000000
#
#                                          Space  Teaching  Publications  \
# School          Department
# Liberal Arts    Chinese               0.000000  0.000032      0.006843
#                 Foreign Languages     0.000219  0.000424      0.000000
#                 History               0.000000  0.000034      0.000000
#                 Arts                  0.000010  0.000131      0.000000
# Sciences        Mathematics           0.000022  0.000033      0.009524
#                 Physics               0.000013  0.000022      0.006270
#                 Chemistry             0.000008  0.000026      0.003606
#                 Earth Sciences        0.000031  0.000044      0.001109
#                 Biology               0.000000  0.000042      0.001159
#                 Biotechnology         0.000856  0.000000      0.000000
# Engineering     Mechanical Eng.       0.000000  0.000014      0.002434
#                 Electrical Eng.       0.000000  0.000016      0.000000
#                 Information Eng.      0.000016  0.000051      0.007024
#                 Chemical Eng.         0.000000  0.000015      0.004014
#                 Resources Eng.        0.000000  0.000032      0.001630
#                 Materials Eng.        0.000000  0.000030      0.000951
#                 Civil Eng.            0.000000  0.000022      0.000685
#                 Hydraulic Eng.        0.000000  0.000000      0.000000
#                 Architecture          0.000000  0.000028      0.000769
#                 Engineering Science   0.000001  0.000029      0.000879
#                 Naval Architecture    0.000000  0.000037      0.001776
#                 Urban Planning        0.000000  0.000043      0.000000
#                 Industrial Design     0.000000  0.000062      0.000000
#                 Aeronautical Eng.     0.000000  0.000008      0.008356
#                 Environmental Eng.    0.000015  0.000000      0.005173
#                 Surveying Eng.        0.000000  0.000041      0.000000
#                 Manufacturing Eng.    0.000216  0.000000      0.000000
#                 Biomedical Eng.       0.000000  0.000000      0.018800
# Management      Industrial Mgmt.      0.000004  0.000029      0.005593
#                 Transportation Mgmt.  0.000000  0.000039      0.002109
#                 Business Admin.       0.000043  0.000029      0.000000
#                 Accountancy           0.000000  0.000056      0.006809
#                 Statistics            0.000000  0.000046      0.000000
# Medicine        Medicine              0.000000  0.000000      0.000000
#                 Nursing               0.000393  0.000033      0.020007
#                 Medical Technology    0.000274  0.000000      0.019790
#                 Occupational Therapy  0.000000  0.000006      0.000000
#                 Physical Therapy      0.000075  0.000000      0.000000
# Social Sciences Political Economy     0.000595  0.000036      0.000000
#                 Education             0.000000  0.000096      0.000000
#                 Law                   0.000984  0.000000      0.000000
#
#                                       Grants (unit:1000)        u_0        TE  \
# School          Department
# Liberal Arts    Chinese                         0.000000  -0.100900  0.968282
#                 Foreign Languages               0.000000  16.000831  1.000000
#                 History                         0.000000  -0.190536  0.660915
#                 Arts                            0.000000  -0.355262  1.000000
# Sciences        Mathematics                     0.000000   0.037731  1.000000
#                 Physics                         0.000000   0.021376  1.000000
#                 Chemistry                       0.000000  -0.018094  0.811823
#                 Earth Sciences                  0.000006  -0.160701  0.791274
#                 Biology                         0.000005  -0.110124  0.711658
#                 Biotechnology                   0.000026  -0.618384  1.000000
# Engineering     Mechanical Eng.                 0.000001  -0.034197  0.854853
#                 Electrical Eng.                 0.000002   0.027833  1.000000
#                 Information Eng.                0.000000  -0.035242  0.981559
#                 Chemical Eng.                   0.000000  -0.075069  1.000000
#                 Resources Eng.                  0.000004  -0.139788  0.640799
#                 Materials Eng.                  0.000004  -0.060398  1.000000
#                 Civil Eng.                      0.000003  -0.046824  0.792643
#                 Hydraulic Eng.                  0.000006  -0.082979  1.000000
#                 Architecture                    0.000003  -0.048191  0.806545
#                 Engineering Science             0.000003  -0.053134  0.781481
#                 Naval Architecture              0.000005  -0.164584  0.705885
#                 Urban Planning                  0.000005  -0.114053  0.830027
#                 Industrial Design               0.000000  -0.173964  1.000000
#                 Aeronautical Eng.               0.000003   0.225161  1.000000
#                 Environmental Eng.              0.000008  -0.065168  1.000000
#                 Surveying Eng.                  0.000005  -0.178402  0.738673
#                 Manufacturing Eng.              0.000028  -0.440423  1.000000
#                 Biomedical Eng.                 0.000000  -0.304400  1.000000
# Management      Industrial Mgmt.                0.000000  -0.121216  0.750417
#                 Transportation Mgmt.            0.000004  -0.163540  0.730052
#                 Business Admin.                 0.000004  -0.082139  1.000000
#                 Accountancy                     0.000000  -0.061239  1.000000
#                 Statistics                      0.000006  -0.160558  0.774072
# Medicine        Medicine                        0.000006   0.732295  1.000000
#                 Nursing                         0.000000  -0.267515  0.590562
#                 Medical Technology              0.000000  -0.297452  1.000000
#                 Occupational Therapy            0.000000  -0.744997  0.771502
#                 Physical Therapy                0.000000  -0.802741  0.802741
# Social Sciences Political Economy               0.000000  -0.388695  1.000000
#                 Education                       0.000000  -0.532870  1.000000
#                 Law                             0.000000  -1.000000  1.000000
#
#                                             OE     SE return to scale
# School          Department
# Liberal Arts    Chinese               0.935939  0.967             IRS
#                 Foreign Languages     1.000000  1.000             DRS
#                 History               0.567983  0.859             IRS
#                 Arts                  0.770042  0.770             IRS
# Sciences        Mathematics           1.000000  1.000             DRS
#                 Physics               1.000000  1.000             DRS
#                 Chemistry             0.804803  0.991             IRS
#                 Earth Sciences        0.717626  0.907             IRS
#                 Biology               0.665280  0.935             IRS
#                 Biotechnology         0.632991  0.633             IRS
# Engineering     Mechanical Eng.       0.852982  0.998             IRS
#                 Electrical Eng.       1.000000  1.000             DRS
#                 Information Eng.      0.962564  0.981             IRS
#                 Chemical Eng.         1.000000  1.000             IRS
#                 Resources Eng.        0.568089  0.887             IRS
#                 Materials Eng.        1.000000  1.000             IRS
#                 Civil Eng.            0.786088  0.992             IRS
#                 Hydraulic Eng.        1.000000  1.000             IRS
#                 Architecture          0.800090  0.992             IRS
#                 Engineering Science   0.759767  0.972             IRS
#                 Naval Architecture    0.608541  0.862             IRS
#                 Urban Planning        0.783546  0.944             IRS
#                 Industrial Design     0.986318  0.986             IRS
#                 Aeronautical Eng.     1.000000  1.000             DRS
#                 Environmental Eng.    1.000000  1.000             IRS
#                 Surveying Eng.        0.659543  0.893             IRS
#                 Manufacturing Eng.    0.822647  0.823             IRS
#                 Biomedical Eng.       1.000000  1.000             IRS
# Management      Industrial Mgmt.      0.702136  0.936             IRS
#                 Transportation Mgmt.  0.631396  0.865             IRS
#                 Business Admin.       1.000000  1.000             IRS
#                 Accountancy           1.000000  1.000             IRS
#                 Statistics            0.688742  0.890             IRS
# Medicine        Medicine              0.963368  0.963             DRS
#                 Nursing               0.433198  0.734             IRS
#                 Medical Technology    0.858524  0.859             IRS
#                 Occupational Therapy  0.453762  0.588             IRS
#                 Physical Therapy      0.528789  0.659             IRS
# Social Sciences Political Economy     1.000000  1.000             IRS
#                 Education             0.808714  0.809             IRS
#                 Law                   0.736035  0.736             IRS

# %%
result.to_csv("DEA_result.csv", float_format='%.6f')

# %%
result_read = (pd.read_csv("DEA_result.csv", index_col=0))
result_read = pd.DataFrame(data=np.array(result_read), columns=result_read.columns, index=IDX)
result_read.head()
# Out:
#                                Personnel Expenses (unit:1000)     Space  \
# School       Department
# Liberal Arts Chinese                   0             0.000164         0
#              Foreign Languages         0                    0  0.000219
#              History                   0             0.000196         0
#              Arts               0.164011                    0     1e-05
# Sciences     Mathematics               0             0.000141   2.2e-05
#
#                                 Teaching Publications Grants (unit:1000)  \
# School       Department
# Liberal Arts Chinese             3.2e-05     0.006843                  0
#              Foreign Languages  0.000424            0                  0
#              History             3.4e-05            0                  0
#              Arts               0.000131            0                  0
# Sciences     Mathematics         3.3e-05     0.009524                  0
#
#                                      u_0        TE        OE     SE  \
# School       Department
# Liberal Arts Chinese             -0.1009  0.968282  0.935939  0.967
#              Foreign Languages   16.0008         1         1      1
#              History           -0.190536  0.660915  0.567983  0.859
#              Arts              -0.355262         1  0.770042   0.77
# Sciences     Mathematics        0.037731         1         1      1
#
#                                return to scale
# School       Department
# Liberal Arts Chinese                       IRS
#              Foreign Languages             DRS
#              History                       IRS
#              Arts                          IRS
# Sciences     Mathematics                   DRS

# %%
## 3D plotting
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D
from numpy.random import rand
from pylab import figure

# %%
plot_data = pd.DataFrame(data=result_read["u_0"])
plot_data["TE"] = list(result_read["TE"])
plot_data["OE"] = list(result_read["OE"])

m = np.array(plot_data)# m is an array of (x,y,z) coordinate triplets

fig = figure(figsize=(10, 20))
ax = Axes3D(fig)

dot_name = deps

for i in range(len(m)): #plot each point + it's index as text above
 ax.scatter(m[i,0],m[i,1],m[i,2], color='b') 
 ax.text(m[i,0],m[i,1],m[i,2], '%s' % (dot_name[i]), size=5, zorder=1, color='k') 

ax.set_zlabel('OE')
ax.set_ylabel('TE')
ax.set_xlabel('u_0')
pyplot.show()

# %%
## find efficient point
best = pd.DataFrame(columns=result_read.columns)
for index, row in result_read.iterrows():
    if row["TE"] == 1:
        if row["OE"] == 1:
            best = best.append(row)
best
# Out:
#                                       Personnel  Expenses (unit:1000)  \
# (Liberal Arts, Foreign Languages)      0.000000              0.000000
# (Sciences, Mathematics)                0.000000              0.000141
# (Sciences, Physics)                    0.000000              0.000096
# (Engineering, Electrical Eng.)         0.017606              0.000000
# (Engineering, Chemical Eng.)           0.008617              0.000054
# (Engineering, Materials Eng.)          0.038462              0.000000
# (Engineering, Hydraulic Eng.)          0.036364              0.000000
# (Engineering, Aeronautical Eng.)       0.000000              0.000115
# (Engineering, Environmental Eng.)      0.049811              0.000000
# (Engineering, Biomedical Eng.)         0.100000              0.000000
# (Management, Business Admin.)          0.029031              0.000000
# (Management, Accountancy)              0.066667              0.000000
# (Social Sciences, Political Economy)   0.000000              0.000000
#
#                                          Space  Teaching  Publications  \
# (Liberal Arts, Foreign Languages)     0.000219  0.000424      0.000000
# (Sciences, Mathematics)               0.000022  0.000033      0.009524
# (Sciences, Physics)                   0.000013  0.000022      0.006270
# (Engineering, Electrical Eng.)        0.000000  0.000016      0.000000
# (Engineering, Chemical Eng.)          0.000000  0.000015      0.004014
# (Engineering, Materials Eng.)         0.000000  0.000030      0.000951
# (Engineering, Hydraulic Eng.)         0.000000  0.000000      0.000000
# (Engineering, Aeronautical Eng.)      0.000000  0.000008      0.008356
# (Engineering, Environmental Eng.)     0.000015  0.000000      0.005173
# (Engineering, Biomedical Eng.)        0.000000  0.000000      0.018800
# (Management, Business Admin.)         0.000043  0.000029      0.000000
# (Management, Accountancy)             0.000000  0.000056      0.006809
# (Social Sciences, Political Economy)  0.000595  0.000036      0.000000
#
#                                       Grants (unit:1000)        u_0   TE   OE  \
# (Liberal Arts, Foreign Languages)               0.000000  16.000831  1.0  1.0
# (Sciences, Mathematics)                         0.000000   0.037731  1.0  1.0
# (Sciences, Physics)                             0.000000   0.021376  1.0  1.0
# (Engineering, Electrical Eng.)                  0.000002   0.027833  1.0  1.0
# (Engineering, Chemical Eng.)                    0.000000  -0.075069  1.0  1.0
# (Engineering, Materials Eng.)                   0.000004  -0.060398  1.0  1.0
# (Engineering, Hydraulic Eng.)                   0.000006  -0.082979  1.0  1.0
# (Engineering, Aeronautical Eng.)                0.000003   0.225161  1.0  1.0
# (Engineering, Environmental Eng.)               0.000008  -0.065168  1.0  1.0
# (Engineering, Biomedical Eng.)                  0.000000  -0.304400  1.0  1.0
# (Management, Business Admin.)                   0.000004  -0.082139  1.0  1.0
# (Management, Accountancy)                       0.000000  -0.061239  1.0  1.0
# (Social Sciences, Political Economy)            0.000000  -0.388695  1.0  1.0
#
#                                        SE return to scale
# (Liberal Arts, Foreign Languages)     1.0             DRS
# (Sciences, Mathematics)               1.0             DRS
# (Sciences, Physics)                   1.0             DRS
# (Engineering, Electrical Eng.)        1.0             DRS
# (Engineering, Chemical Eng.)          1.0             IRS
# (Engineering, Materials Eng.)         1.0             IRS
# (Engineering, Hydraulic Eng.)         1.0             IRS
# (Engineering, Aeronautical Eng.)      1.0             DRS
# (Engineering, Environmental Eng.)     1.0             IRS
# (Engineering, Biomedical Eng.)        1.0             IRS
# (Management, Business Admin.)         1.0             IRS
# (Management, Accountancy)             1.0             IRS
# (Social Sciences, Political Economy)  1.0             IRS

# %%
best.index[0][1]
# Out:
# 'Foreign Languages'

# %%
def get_value_df(df):
    df_copy = df.copy()
    for dep in range(len(df_copy.index)):
        for i in range(3):
            df_copy.iloc[dep, i] = X[df_copy.index[dep][1]][i]
            df_copy.iloc[dep, i+3] = Y[df_copy.index[dep][1]][i]
    return df_copy

# %% [markdown]
# ## (c) i) Which dept. does show a better performance? Why?

# %% [markdown]
# 依照原本表格的順序，其 TE、OE 皆為 1 的學校如下表所式：
# 以下各個科系都有其輸出較優勢的地方（如 Electrical Eng.、Aeronautical Eng. 等)；同時，也有運用較少資源的科系（如 Biomedical Eng.、Political Economy）
# 利用擅長的能力最大化輸出，則可以讓其效率提昇

# %%
best_value = get_value_df(best)
best_value
# Out:
#                                       Personnel  Expenses (unit:1000)  \
# (Liberal Arts, Foreign Languages)          36.5                8387.4
# (Sciences, Mathematics)                    29.5                6426.2
# (Sciences, Physics)                        44.8                9360.1
# (Engineering, Electrical Eng.)             56.8               17607.4
# (Engineering, Chemical Eng.)               46.0               11161.6
# (Engineering, Materials Eng.)              26.0                8975.2
# (Engineering, Hydraulic Eng.)              27.5                8506.4
# (Engineering, Aeronautical Eng.)           57.5                8718.2
# (Engineering, Environmental Eng.)          19.0                6593.6
# (Engineering, Biomedical Eng.)             10.0                4490.1
# (Management, Business Admin.)              25.8                7795.6
# (Management, Accountancy)                  15.0                4909.1
# (Social Sciences, Political Economy)       19.0                3950.7
#
#                                         Space  Teaching  Publications  \
# (Liberal Arts, Foreign Languages)      4574.0   40105.0           0.0
# (Sciences, Mathematics)                4175.0   23647.0          27.0
# (Sciences, Physics)                    8184.0   27613.0          66.0
# (Engineering, Electrical Eng.)        25770.0   46582.0         161.0
# (Engineering, Chemical Eng.)          27410.0   28664.0         120.0
# (Engineering, Materials Eng.)          6326.0   16284.0          95.3
# (Engineering, Hydraulic Eng.)          9435.0   13059.0          17.5
# (Engineering, Aeronautical Eng.)      12550.0   18029.0          70.0
# (Engineering, Environmental Eng.)      3548.0    8609.0          35.0
# (Engineering, Biomedical Eng.)         3937.0    6263.0          37.0
# (Management, Business Admin.)          5815.0   26923.0           1.5
# (Management, Accountancy)              4085.0   16391.0           2.0
# (Social Sciences, Political Economy)   1682.0   16964.0           0.0
#
#                                       Grants (unit:1000)        u_0   TE   OE  \
# (Liberal Arts, Foreign Languages)                 1543.5  16.000831  1.0  1.0
# (Sciences, Mathematics)                          10518.6   0.037731  1.0  1.0
# (Sciences, Physics)                              60912.4   0.021376  1.0  1.0
# (Engineering, Electrical Eng.)                  160768.2   0.027833  1.0  1.0
# (Engineering, Chemical Eng.)                     58183.2  -0.075069  1.0  1.0
# (Engineering, Materials Eng.)                   101281.4  -0.060398  1.0  1.0
# (Engineering, Hydraulic Eng.)                   165046.9  -0.082979  1.0  1.0
# (Engineering, Aeronautical Eng.)                153755.8   0.225161  1.0  1.0
# (Engineering, Environmental Eng.)                91704.7  -0.065168  1.0  1.0
# (Engineering, Biomedical Eng.)                   28470.8  -0.304400  1.0  1.0
# (Management, Business Admin.)                    32889.0  -0.082139  1.0  1.0
# (Management, Accountancy)                         2703.6  -0.061239  1.0  1.0
# (Social Sciences, Political Economy)              1322.2  -0.388695  1.0  1.0
#
#                                        SE return to scale
# (Liberal Arts, Foreign Languages)     1.0             DRS
# (Sciences, Mathematics)               1.0             DRS
# (Sciences, Physics)                   1.0             DRS
# (Engineering, Electrical Eng.)        1.0             DRS
# (Engineering, Chemical Eng.)          1.0             IRS
# (Engineering, Materials Eng.)         1.0             IRS
# (Engineering, Hydraulic Eng.)         1.0             IRS
# (Engineering, Aeronautical Eng.)      1.0             DRS
# (Engineering, Environmental Eng.)     1.0             IRS
# (Engineering, Biomedical Eng.)        1.0             IRS
# (Management, Business Admin.)         1.0             IRS
# (Management, Accountancy)             1.0             IRS
# (Social Sciences, Political Economy)  1.0             IRS

# %% [markdown]
# ## (c) ii) Which dept. does show a poor performance? Why? Any suggestion to improve productivity?
# 以下為最糟的科系：Nursing 的各項指標
# 因其 IRS，故可考慮增加規模來達到 MPSS；但在此之前，可先考量減少其 expences 的花費，並增加 Teaching 以及 Grants，以提昇整體效率

# %%
## worst
temp = 1
for index, row in result_read.iterrows():
    if row["TE"] < temp:
        worst = row.copy()
        temp = row["TE"]
worst
# Out:
# Personnel               0.008559
# Expenses (unit:1000)           0
# Space                   0.000393
# Teaching                 3.3e-05
# Publications            0.020007
# Grants (unit:1000)             0
# u_0                    -0.267515
# TE                      0.590562
# OE                      0.433198
# SE                         0.734
# return to scale              IRS
# Name: (Medicine, Nursing), dtype: object

# %%
## worst data
VALUE_DATA.loc[worst.name]
# Out:
# Personnel                   17
# Expenses (unit:1000)    5212.2
# Space                     2175
# Teaching                  6500
# Publications               5.5
# Grants (unit:1000)      5399.1
# Name: (Medicine, Nursing), dtype: object

# %% [markdown]
# ## (d) i) Which school does show a better average performance? Why?
# #### 以下是根據學校的效率做平均的結果：
# Social Sciences 因為在投入的成本偏低，而在 Teaching_avg 與 Grants_avg 都不致於太差，故其 TE 與 OE 均在高位
# ## (d) ii) Which school does show a poor average performance? Why? Any suggestion to improve productivity?
# Medicine 的平均表現比較差，在上小題的科系效率都沒有該 Medicine 的科系便可略之一二，與其表現鄰近的 Engineering 相比，Medicine 在成本上高出較多，並且，成本方面都位居平均高位，但輸出方面卻不盡然，Medicine 可以考慮在能負擔的情況下，降低成本。可考慮從與其他學院差距比例最多的 Personnel_avg 方面著手

# %%
## split by school
COL_avg = ["Personnel_avg", "Expenses_avg", "Space_avg", "Teaching_avg", "Publications_avg", "Grants_avg", "TE_avg", "OE_avg", "SE_avg"]
schools_e = pd.DataFrame(columns=COL_avg)
for school in schools_unique:
    schools_e = schools_e.append(pd.DataFrame(data=[[
        np.mean(np.array(VALUE_DATA["Personnel"][school])), 
        np.mean(np.array(VALUE_DATA["Expenses (unit:1000)"][school])), 
        np.mean(np.array(VALUE_DATA["Space"][school])), 
        np.mean(np.array(VALUE_DATA["Teaching"][school])), 
        np.mean(np.array(VALUE_DATA["Publications"][school])), 
        np.mean(np.array(VALUE_DATA["Grants (unit:1000)"][school])), 
        np.mean(np.array(result_read["TE"][school])), 
        np.mean(np.array(result_read["OE"][school])), 
        np.mean(np.array(result_read["SE"][school])), 
        ]], columns=COL_avg, index=[school]))
schools_e
# Out:
#                  Personnel_avg  Expenses_avg     Space_avg  Teaching_avg  \
# Liberal Arts         25.500000   5748.075000   3838.750000  21210.000000
# Sciences             24.350000   7003.466667   5542.833333  16011.666667
# Engineering          27.800000   8831.111111  10610.388889  17244.277778
# Management           21.680000   5843.740000   4831.200000  17156.200000
# Medicine             51.260000  10995.060000   7474.000000  14315.400000
# Social Sciences      11.833333   2726.666667   1306.333333   9265.666667
#
#                  Publications_avg    Grants_avg    TE_avg    OE_avg    SE_avg
# Liberal Arts             1.250000   2771.425000  0.907299  0.818491  0.899000
# Sciences                29.000000  31141.316667  0.885792  0.803450  0.911000
# Engineering             44.044444  66090.844444  0.896248  0.866121  0.962778
# Management               8.000000  14985.300000  0.850908  0.804455  0.938200
# Medicine                92.800000  66535.700000  0.832961  0.647528  0.760600
# Social Sciences          2.166667   4076.233333  1.000000  0.848250  0.848333
